# %% [markdown]
# Description:
# Implement TF-IDF from scratch using the equations presented in the lecture then apply it to
# a 4 different pdf documents from your choice. P.S. you can generate the documents.
#
# Requirements:
# 1. Preprocess texts (Tokenization & Case normalization “Lowering case” & Punctuation
# removal)
# 2. Compute Term Frequency (TF) and Inverse Document Frequency (IDF).
# 3. Display the words with the highest TF-IDF value.
# 4. Use TF-IDF to encode/embed your documents.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import re
import math
from collections import Counter
from sklearn.preprocessing import normalize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {"should've", "that'll", 'then', 'from', 'to', 'i', 'is', 'what', 'by', 'why', 'y', 'themselves', 'll', 'wasn', "weren't", 'down', 'too', 'more', 'be', 'himself', 'both', 'they', 'couldn', 'for', 'now', "she'd", "i've", 'there', 'doesn', 'did', 'these', 'aren', 'because', "shouldn't", 'you', 'as', 'can', 'when', 'am', 'against', 'in', 'through', 'was', "won't", "he's", 'itself', 'about', 'does', 'until', "wouldn't", "you're", 'your', 'have', 'over', 'ain', "it'll", "aren't", 'been', 'where', 'no', 'needn', 'd', 'we', 'didn', "she's", "they'll", 'the', 'her', 'he', 'hers', "doesn't", "mustn't", 'shan', 'mightn', "they're", 'above', 'ma', 'an', "i'd", 'than', 'had', 'were', 'out', "it's", 'who', 'few', "she'll", "i'll", 'so', 'weren', 'all', 'it', 'own', 'between', 'some', 'how', 'just', 'shouldn', 'most', 'm', 'ourselves', 'yours', 'she', 'don', 'each', "didn't", 'not', 'do', 'once', 'at', 'o', "you'd", "we've", 'his', 'doing', "don't", 'nor', "we're", 'such', 'theirs', 'yourselves', 'up', 's', 'again', 'if', 'under', "you'll", 'here', "isn't", "mightn't", 'hasn', "couldn't", 'isn', 'their', "hasn't", 'him', 'me', 'that', 'them', 'of', "they've", 'which', 'won', 'has', 'mustn', "needn't", 'further', 'having', "shan't", 'very', "haven't", 'should', 'wouldn', 'whom', 'same', 'during', 're', "he'd", 'hadn', 'will', 'other', 'but', "i'm", 'off', 'ours', 'into', 'or', 'and', 'on', "he'll", "they'd", 't', 'below', 've', "we'll", 'its', 'yourself', 'with', 'my', 'after', 'haven', "we'd", 'being', 'any', 'those', "it'd", 'a', 'myself', 'are', "you've", 'this', 'only', "hadn't", "wasn't", 'while', 'our', 'herself', 'before'}

# %%
class TextPreprocessing:
  def __init__(self, text):
    self.text = text
    self.stop_words = set(stopwords.words('english'))

  def _clean_text(self, text_to_clean):
    # if there is no string in the sentece
    if not isinstance(text_to_clean, str):  # Ensure the second argument is `str`
      return ""
    # Keep only letters and spaces
    cleaned_text = re.sub(r"[^a-zA-Z\s]", "", text_to_clean)
    return cleaned_text

  def fit(self):
    cleaned_text = self._clean_text(self.text)
    Lsent = cleaned_text.lower()
    sent_tok = word_tokenize(Lsent)
    sent_tok_filtered = set([word for word in sent_tok if word not in self.stop_words])
    return sent_tok_filtered

# %%
sentence = "Mina, Filopater, Martina, Youssef and (Mina & Martina & Filopater & Youssef) again for the assignment.!!!"
txtprepros = TextPreprocessing(sentence)
finaltxt = txtprepros.fit()
print(finaltxt)
# Out:
# {'mina', 'martina', 'filopater', 'assignment', 'youssef'}

# %%
documents = [
"Hany love going to school",
"The school is far from Sara home",
"Hany likes apple more than banana",
"Sara likes apple too"
]

preprocessed_documents = []
for doc in documents:
    preprocessor = TextPreprocessing(doc)
    preprocessed_documents.append(preprocessor.fit())

# Output the preprocessed documents
for i, doc in enumerate(preprocessed_documents):
    print(f"Document {i+1}: {doc}")
# Out:
# Document 1: {'love', 'school', 'going', 'hany'}
# Document 2: {'school', 'sara', 'home', 'far'}
# Document 3: {'banana', 'apple', 'hany', 'likes'}
# Document 4: {'sara', 'apple', 'likes'}

# %%
# 2. Compute Term Frequency (TF)
def compute_tf(doc):
    term_count = Counter(doc)
    total_terms = len(doc)
    tf = {term: count / total_terms for term, count in term_count.items()}
    return tf

tf_list = [compute_tf(doc) for doc in preprocessed_documents]
print(tf_list)
# Out:
# [{'love': 0.25, 'school': 0.25, 'going': 0.25, 'hany': 0.25}, {'school': 0.25, 'sara': 0.25, 'home': 0.25, 'far': 0.25}, {'banana': 0.25, 'apple': 0.25, 'hany': 0.25, 'likes': 0.25}, {'sara': 0.3333333333333333, 'apple': 0.3333333333333333, 'likes': 0.3333333333333333}]

# %%
# 3. Compute Inverse Document Frequency (IDF)
def compute_idf(all_docs):
    total_docs = len(all_docs)
    idf = {}
    all_terms = set(term for doc in all_docs for term in doc)
    for term in all_terms:
        doc_count = sum(1 for doc in all_docs if term in doc)
        idf[term] = math.log((1 + total_docs) / (1 + doc_count)) + 1
    return idf

idf = compute_idf(preprocessed_documents)
print(idf)
# Out:
# {'sara': 1.5108256237659907, 'far': 1.916290731874155, 'love': 1.916290731874155, 'apple': 1.5108256237659907, 'banana': 1.916290731874155, 'home': 1.916290731874155, 'likes': 1.5108256237659907, 'school': 1.5108256237659907, 'going': 1.916290731874155, 'hany': 1.5108256237659907}

# %%
# 4. Compute TF-IDF
def compute_tfidf(tf, idf):
    tfidf = {term: tf_val * idf[term] for term, tf_val in tf.items()}
    return tfidf

tfidf_list = [compute_tfidf(tf, idf) for tf in tf_list]
print(tfidf_list)
# Out:
# [{'love': 0.4790726829685388, 'school': 0.3777064059414977, 'going': 0.4790726829685388, 'hany': 0.3777064059414977}, {'school': 0.3777064059414977, 'sara': 0.3777064059414977, 'home': 0.4790726829685388, 'far': 0.4790726829685388}, {'banana': 0.4790726829685388, 'apple': 0.3777064059414977, 'hany': 0.3777064059414977, 'likes': 0.3777064059414977}, {'sara': 0.5036085412553302, 'apple': 0.5036085412553302, 'likes': 0.5036085412553302}]

# %%
# Normalize TF-IDF vectors
def encode_documents(tfidf_list):
    terms = sorted(idf.keys())
    doc_vectors = []
    for tfidf in tfidf_list:
        vector = [tfidf.get(term, 0) for term in terms]
        doc_vectors.append(vector)
    return normalize(doc_vectors)

encoded_docs = encode_documents(tfidf_list)

# Display Words with Highest TF-IDF Value in Each Document
for idx, tfidf in enumerate(tfidf_list):
    sorted_terms = sorted(tfidf.items(), key=lambda x: x[1], reverse=True)[:3]
    print(f"Top words in Document {idx + 1}: {sorted_terms}")

# Display Encoded Document Vectors
print("\nEncoded Document Vectors:")
for idx, vec in enumerate(encoded_docs):
    print(f"Document {idx + 1}: {vec}")
# Out:
# Top words in Document 1: [('love', 0.4790726829685388), ('going', 0.4790726829685388), ('school', 0.3777064059414977)]
# Top words in Document 2: [('home', 0.4790726829685388), ('far', 0.4790726829685388), ('school', 0.3777064059414977)]
# Top words in Document 3: [('banana', 0.4790726829685388), ('apple', 0.3777064059414977), ('hany', 0.3777064059414977)]
# Top words in Document 4: [('sara', 0.5036085412553302), ('apple', 0.5036085412553302), ('likes', 0.5036085412553302)]
#
# Encoded Document Vectors:
# Document 1: [0.         0.         0.         0.55528266 0.43779123 0.
#  0.         0.55528266 0.         0.43779123]
# Document 2: [0.         0.         0.55528266 0.         0.         0.55528266
#  0.         0.         0.43779123 0.43779123]
# Document 3: [0.46580855 0.59081908 0.         0.         0.46580855 0.
#  0.46580855 0.         0.         0.        ]
# Document 4: [0.57735027 0.         0.         0.         0.         0.
#  0.57735027 0.         0.57735027 0.        ]

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.25.4-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.4-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 46.8 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.25.4

# %%
import fitz

# %% [markdown]
# Each line element in list

# %%
Pdfs = ["Football_Basics.pdf", "Tennis SG.pdf", "NLPTrends.pdf", "Relationships.pdf"]

list_of_docs = []

for pdf_path in Pdfs:
    doc = fitz.open(pdf_path)

    Doc = []  # List to store all lines from the PDF

    for page in doc:
        page_text = page.get_text()
        lines = page_text.split('\n')  # Split the text into lines
        Doc.extend(lines)  # Add the lines to the list

    list_of_docs.append(Doc)

# %%
for docs in list_of_docs:
  fpreprocessed_documents = []
  for doc in docs:
    preprocessor = TextPreprocessing(doc)
    fpreprocessed_documents.append(preprocessor.fit())

  # Output the preprocessed documents
  for i, doc in enumerate(fpreprocessed_documents):
      print(f"Document {i+1}: {doc}")

  print(100*"#")
# Out:
# Document 1: {'football', 'basics'}
# Document 2: {'check', 'new', 'need', 'games', 'football', 'youre', 'time', 'following', 'difficult', 'look'}
# Document 3: {'terms'}
# Document 4: {'game', 'basics'}
# Document 5: {'advance', 'offense', 'football', 'possession', 'tries', 'called', 'man', 'ball', 'team', 'one'}
# Document 6: {'points', 'score', 'running', 'line', 'ball', 'throwing', 'goal', 'crossing', 'fieldby'}
# Document 7: {'area', 'defense', 'players', 'also', 'called', 'zone', 'team', 'end', 'getting'}
# Document 8: {'make', 'offensive', 'possession', 'tries', 'ball', 'stop', 'team', 'give'}
# Document 9: {'teams', 'offensive', 'possession', 'score', 'roles', 'give', 'forced', 'defensive', 'switch'}
# Document 10: {'forth', 'defense', 'offense', 'four', 'back', 'team', 'defensive', 'goes'}
# Document 11: {'played', 'game', 'quarters'}
# Document 12: {'playing', 'field'}
# Document 13: {'little', 'markings', 'field', 'yards', 'white', 'called', 'yard', 'measures', 'long', 'wide', 'markers'}
# Document 14: {'keep', 'track', 'players', 'part', 'officials', 'ball', 'help', 'fans', 'important', 'probably'}
# Document 15: {'field', 'points', 'add', 'yards', 'zone', 'end', 'additional'}
# Document 16: {'ballgets', 'offense', 'possession', 'ball', 'zone', 'team', 'opponents', 'end'}
# Document 17: {'points', 'score'}
# Document 18: {'players'}
# Document 19: {'section', 'players', 'field', 'offense', 'see', 'team', 'separate', 'units'}
# Document 20: {'section', 'defense', 'players', 'possession', 'line', 'ball', 'stop', 'see', 'team'}
# Document 21: {'teams', 'goals', 'kickoffs', 'special', 'field', 'offense', 'come', 'situations', 'punts', 'kicking'}
# Document 22: {'field', 'players', 'team', 'one', 'time'}
# Document 23: {'offense'}
# Document 24: {'quarterback', 'offense', 'whichever', 'possession', 'ball', 'team', 'receivers', 'wide'}
# Document 25: {'tight', 'quarterback', 'backs', 'running', 'leader', 'ball', 'ends', 'legally', 'handle'}
# Document 26: {'playmaker', 'team'}
# Document 27: {'offensive', 'players'}
# Document 28: set()
# Document 29: {'passes', 'quarterback', 'qb', 'hands', 'ball'}
# Document 30: set()
# Document 31: {'center', 'defense', 'qb', 'snaps', 'ball', 'blocks'}
# Document 32: set()
# Document 33: {'keep', 'defense', 'guards', 'tackles', 'bay'}
# Document 34: set()
# Document 35: {'thrown', 'qb', 'ball', 'receivers', 'catch', 'wide'}
# Document 36: set()
# Document 37: {'take', 'backs', 'running', 'ball', 'run'}
# Document 38: set()
# Document 39: {'passes', 'defense', 'tight', 'also', 'block', 'ends', 'catches'}
# Document 40: {'defense'}
# Document 41: {'keep', 'job', 'work', 'defense', 'men', 'offense', 'together', 'stop', 'team', 'defensive'}
# Document 42: {'offense', 'advancing', 'toward', 'defenses', 'zone', 'end'}
# Document 43: set()
# Document 44: set()
# Document 45: {'players', 'defensive'}
# Document 46: set()
# Document 47: {'pass', 'forward', 'linebackers', 'defend', 'qb', 'stop', 'run', 'tackle', 'push'}
# Document 48: set()
# Document 49: {'tackles', 'offensive', 'headtohead', 'line', 'battles', 'ends', 'defensive'}
# Document 50: set()
# Document 51: {'cornerbacks', 'pass', 'receiver', 'qb', 'defend', 'help', 'wide', 'safeties'}
# Document 52: {'stop', 'run'}
# Document 53: set()
# Document 54: {'game', 'play'}
# Document 55: {'timing'}
# Document 56: {'four', 'games', 'divided', 'separated', 'quarters', 'halftime', 'minute', 'break'}
# Document 57: {'officiating'}
# Document 58: {'umpire', 'referee', 'officials', 'linesman', 'game', 'start', 'typically', 'nyfl', 'may'}
# Document 59: {'teams', 'agreed', 'officials', 'three', 'upon'}
# Document 60: {'kickoff'}
# Document 61: {'tee', 'line', 'game', 'ball', 'defenses', 'yard', 'starts', 'kickoff', 'placed', 'kicking'}
# Document 62: {'special', 'return', 'kicks', 'offense', 'try', 'kick', 'ball', 'man', 'kicker', 'placekicker'}
# Document 63: {'advance', 'offense', 'begin', 'point', 'running', 'ball', 'catch', 'stopped'}
# Document 64: {'series', 'offensive', 'caught', 'kick', 'drive', 'zone', 'offenses', 'plays', 'end', 'kickoff'}
# Document 65: {'kneel', 'sign', 'returner', 'touchback', 'signal', 'ball', 'zone', 'run', 'either', 'end'}
# Document 66: {'offense', 'begins', 'line', 'ball', 'stop', 'yard', 'play', 'placed'}
# Document 67: {'first'}
# Document 68: {'much', 'progress', 'offensive', 'yardage', 'football', 'tries', 'yards', 'game', 'team', 'measured', 'get'}
# Document 69: {'try', 'offense', 'move', 'closer', 'time', 'four', 'ball', 'zone', 'gets', 'opponents', 'end'}
# Document 70: {'moves', 'chances', 'offensive', 'gain', 'downs', 'yards', 'successfully', 'ball', 'team'}
# Document 71: {'loses', 'set', 'four', 'another', 'offense', 'fails', 'earns', 'first', 'gain', 'downs', 'yards'}
# Document 72: {'defense', 'prevent', 'offense', 'possession', 'scoring', 'tries', 'also', 'ball'}
# Document 73: {'reaches', 'gaining', 'offense', 'first', 'fourth', 'yards', 'kick', 'needed', 'ball', 'punt'}
# Document 74: {'field', 'away', 'forces', 'drive', 'team', 'begin'}
# Document 75: {'moving', 'ball'}
# Document 76: {'pass', 'field', 'begins', 'position', 'snap', 'line', 'run', 'play', 'scrimmage'}
# Document 77: {'player', 'center', 'quarterback', 'front', 'begins', 'code', 'loudly', 'calls', 'play'}
# Document 78: {'passes', 'quarterback', 'snaps', 'legs', 'ball', 'either', 'throw'}
# Document 79: {'ball', 'run', 'hand'}
# Document 80: set()
# Document 81: {'advance', 'main', 'two', 'offense', 'first', 'called', 'ball', 'run', 'ways'}
# Document 82: {'quarterback', 'gain', 'tries', 'back', 'hands', 'running', 'ball', 'occurs'}
# Document 83: {'quarterback', 'players', 'eluding', 'also', 'yards', 'run', 'many', 'possible', 'allowed', 'defensive'}
# Document 84: {'ball'}
# Document 85: set()
# Document 86: set()
# Document 87: {'pass', 'usually', 'running', 'ball', 'alternative', 'throw'}
# Document 88: {'player', 'quarterback', 'pass', 'another', 'passing', 'times', 'though', 'ball', 'may'}
# Document 89: {'defense', 'pass', 'anyone', 'offensive', 'ball', 'confuse', 'team', 'long', 'allowed', 'actually'}
# Document 90: {'thrown', 'complete', 'pass', 'behind', 'line', 'caught', 'ball', 'scrimmage'}
# Document 91: {'player', 'tight', 'usually', 'another', 'offensive', 'receiver', 'hits', 'ball', 'end', 'wide', 'ground'}
# Document 92: {'someone', 'pass', 'incomplete', 'called', 'catches'}
# Document 93: {'tackle'}
# Document 94: {'ground', 'defense', 'prevents', 'offense', 'advancing', 'carrier', 'ball', 'bringing'}
# Document 95: {'player', 'knees', 'touch', 'also', 'ends', 'tackled', 'one', 'play', 'ground'}
# Document 96: {'bounds', 'player', 'runs'}
# Document 97: {'turnovers'}
# Document 98: {'turn', 'advance', 'offense', 'football', 'accidentally', 'zone', 'trying', 'ball', 'end', 'may'}
# Document 99: {'one', 'ways', 'defense', 'two'}
# Document 100: set()
# Document 101: {'player', 'field', 'thats', 'drops', 'carrier', 'ball', 'passer', 'fumble'}
# Document 102: {'recovers', 'diving', 'ball', 'run', 'team', 'either', 'fumble', 'recover'}
# Document 103: {'ball', 'retainspossession', 'getsor'}
# Document 104: set()
# Document 105: {'regain', 'defense', 'interception', 'possession', 'aggressive', 'ball', 'catching'}
# Document 106: {'passes', 'recoveries', 'players', 'meant', 'team', 'intercepting', 'fumble'}
# Document 107: {'interceptions', 'also', 'back', 'touchdowns', 'zone', 'run', 'end', 'referred', 'pick'}
# Document 108: set()
# Document 109: {'terms', 'definitions', 'helpful'}
# Document 110: {'quarterback', 'audible', 'changes', 'football', 'line', 'play', 'scrimmage'}
# Document 111: set()
# Document 112: {'area', 'field', 'football', 'backfield', 'behind', 'line', 'scrimmage'}
# Document 113: set()
# Document 114: {'players', 'backs', 'football', 'halfback', 'running', 'include', 'fullback'}
# Document 115: set()
# Document 116: {'rushes', 'players', 'try', 'usual', 'football', 'team', 'blitz', 'play', 'sack', 'defensive'}
# Document 117: {'quarterback'}
# Document 118: set()
# Document 119: {'player', 'prevent', 'offensive', 'football', 'carrier', 'blocking', 'team', 'defensive', 'getting'}
# Document 120: {'hold', 'opponent', 'arms', 'onto', 'use', 'bodies', 'grab', 'blockers', 'may', 'way', 'get'}
# Document 121: set()
# Document 122: {'catching', 'hit', 'pass', 'prevent', 'receiver', 'bumpandrun', 'follow', 'defenders'}
# Document 123: {'pass'}
# Document 124: set()
# Document 125: {'eligible', 'players', 'receiver', 'offense', 'forward', 'football', 'certain', 'rules', 'catch', 'allowed'}
# Document 126: {'eligible', 'linemen', 'quarterback', 'pass', 'referee', 'snap', 'notify', 'unless'}
# Document 127: {'stand', 'linemen', 'must', 'least', 'behind', 'line', 'yard', 'one', 'scrimmage'}
# Document 128: set()
# Document 129: {'player', 'encroachment', 'center', 'neutral', 'football', 'contact', 'penalty', 'zone'}
# Document 130: {'snap', 'prior', 'occurs'}
# Document 131: set()
# Document 132: {'area', 'touchdown', 'football', 'must', 'score', 'enter', 'zone', 'team', 'end'}
# Document 133: set()
# Document 134: {'scored', 'point', 'touchdown', 'football', 'score', 'extra', 'team', 'opportunity'}
# Document 135: {'via', 'points', 'point', 'conversion', 'pointaftertouchdown'}
# Document 136: set()
# Document 137: {'player', 'advance', 'return', 'fair', 'making', 'football', 'kick', 'catch', 'kickoff', 'decide', 'punt'}
# Document 138: {'signals', 'raising', 'fair', 'football', 'must', 'hand', 'one', 'air', 'catch', 'waving'}
# Document 139: set()
# Document 140: {'field', 'uprights', 'goalpost', 'football', 'must', 'kick', 'crossbar', 'kicker', 'goal'}
# Document 141: {'kicked', 'points', 'football', 'gets', 'team'}
# Document 142: set()
# Document 143: {'player', 'thrown', 'quarterback', 'pass', 'forward', 'towards', 'football', 'typically'}
# Document 144: {'thrown', 'pass', 'forward', 'football', 'line', 'team', 'opponents', 'one', 'goal', 'play', 'scrimmage'}
# Document 145: {'thrown', 'must', 'behind', 'line', 'scrimmage'}
# Document 146: set()
# Document 147: {'whether', 'forward', 'progress', 'regardless', 'football', 'carrier', 'moved', 'spot'}
# Document 148: {'pushed', 'backwards', 'spot'}
# Document 149: set()
# Document 150: {'player', 'whoever', 'football', 'drops', 'gain', 'possession', 'team', 'picks', 'fumble'}
# Document 151: set()
# Document 152: {'goalpost', 'football', 'must', 'kick', 'score', 'extra', 'zone', 'kicker', 'end', 'structure'}
# Document 153: {'goal', 'point', 'field'}
# Document 154: set()
# Document 155: {'player', 'holding', 'movement', 'grasping', 'onto', 'stops', 'football', 'penalty', 'opponent'}
# Document 156: {'body', 'uniform'}
# Document 157: set()
# Document 158: {'quarterback', 'pass', 'throws', 'incomplete', 'grounding', 'intentional', 'penalty', 'avoid', 'purposely'}
# Document 159: {'sack'}
# Document 160: set()
# Document 161: {'player', 'defense', 'pass', 'interception', 'football', 'caught'}
# Document 162: set()
# Document 163: {'happens', 'player', 'kicks', 'football', 'start', 'team', 'kickoff'}
# Document 164: {'second', 'overtime', 'half', 'score', 'game'}
# Document 165: set()
# Document 166: {'teams', 'thrown', 'backwards', 'pass', 'players', 'lateral', 'football', 'line', 'may', 'scrimmage'}
# Document 167: {'per', 'want', 'times', 'football', 'many', 'play'}
# Document 168: set()
# Document 169: {'field', 'place', 'football', 'next', 'spotted', 'line', 'starts', 'play', 'scrimmage'}
# Document 170: set()
# Document 171: {'players', 'offensive', 'football', 'line', 'start', 'lineman', 'play', 'defensive', 'scrimmage'}
# Document 172: set()
# Document 173: {'ground', 'area', 'defense', 'offense', 'neutral', 'football', 'zone', 'sits'}
# Document 174: {'play'}
# Document 175: set()
# Document 176: {'defense', 'cover', 'pass', 'nickel', 'brings', 'back', 'help', 'play', 'th', 'defensive'}
# Document 177: set()
# Document 178: {'players', 'part', 'football', 'body', 'line', 'penalty', 'occurs', 'offside', 'beyond', 'scrimmage'}
# Document 179: {'snapped', 'football'}
# Document 180: set()
# Document 181: {'keep', 'quarterback', 'pass', 'players', 'away', 'offensive', 'protection', 'football', 'blocking', 'defenders'}
# Document 182: {'give', 'time', 'football', 'throw'}
# Document 183: set()
# Document 184: {'quarterback', 'pass', 'tries', 'defender', 'blockers', 'rush', 'sack', 'get'}
# Document 185: set()
# Document 186: {'cause', 'personal', 'player', 'injury', 'another', 'intent', 'football', 'foul', 'penalty', 'action'}
# Document 187: set()
# Document 188: {'held', 'place', 'football', 'tries', 'kick', 'post', 'kicker', 'goal'}
# Document 189: {'another', 'player', 'finger', 'ground'}
# Document 190: set()
# Document 191: {'make', 'quarterback', 'pass', 'football', 'playaction', 'tries', 'fakes', 'handing'}
# Document 192: set()
# Document 193: {'protected', 'area', 'quarterback', 'stands', 'pocket', 'blockers', 'rush'}
# Document 194: set()
# Document 195: {'kicks', 'rather', 'football', 'downs', 'team', 'loose', 'punt'}
# Document 196: {'holds', 'kicks', 'football', 'hands', 'kicker', 'team'}
# Document 197: set()
# Document 198: {'player', 'center', 'quarterback', 'football', 'takes', 'snap', 'starts', 'play'}
# Document 199: {'passes', 'runs', 'player', 'another', 'football', 'hands', 'either'}
# Document 200: set()
# Document 201: {'players', 'catch', 'football', 'receivers'}
# Document 202: set()
# Document 203: {'player', 'rush', 'football', 'runs'}
# Document 204: set()
# Document 205: {'quarterback', 'behind', 'line', 'tackled', 'sack', 'scrimmage'}
# Document 206: set()
# Document 207: {'player', 'defense', 'points', 'football', 'safety', 'zone', 'gets', 'tackled', 'end'}
# Document 208: {'kick', 'free'}
# Document 209: set()
# Document 210: {'runs', 'quarterback', 'scrambling', 'football', 'trying', 'sacked', 'around', 'get'}
# Document 211: set()
# Document 212: {'center', 'player', 'standing', 'football', 'hike', 'called', 'snap', 'hands', 'legs', 'sometimes'}
# Document 213: {'quarterback', 'usually', 'behind', 'start', 'play'}
# Document 214: set()
# Document 215: {'teams', 'special', 'players', 'involved', 'football', 'plays', 'kicking'}
# Document 216: set()
# Document 217: {'official', 'football', 'next', 'decides', 'line', 'start', 'play', 'spot', 'scrimmage'}
# Document 218: set()
# Document 219: {'tackle'}
# Document 220: set()
# Document 221: {'player', 'two', 'offensive', 'football', 'position', 'line', 'play', 'defensive'}
# Document 222: {'center', 'side', 'nose', 'guard'}
# Document 223: {'player', 'touch', 'football', 'carrier', 'causes', 'ground'}
# Document 224: {'considered'}
# Document 225: set()
# Document 226: {'player', 'main', 'object', 'touchdown', 'football', 'zone', 'within', 'end', 'control'}
# Document 227: {'points', 'gets', 'team'}
# Document 228: set()
# Document 229: {'loses', 'interception', 'turnover', 'possession', 'football', 'team', 'either', 'one', 'fumble'}
# Document 230: set()
# Document 231: set()
# Document 232: set()
# ####################################################################################################
# Document 1: {'rules', 'tennis'}
# Document 2: {'guide', 'study'}
# Document 3: set()
# Document 4: set()
# Document 5: {'tennis', 'court'}
# Document 6: set()
# Document 7: set()
# Document 8: set()
# Document 9: set()
# Document 10: set()
# Document 11: set()
# Document 12: {'alley', 'doubles'}
# Document 13: set()
# Document 14: set()
# Document 15: set()
# Document 16: {'line', 'side', 'doubles'}
# Document 17: set()
# Document 18: {'line', 'side', 'singles'}
# Document 19: {'back', 'court'}
# Document 20: set()
# Document 21: set()
# Document 22: set()
# Document 23: set()
# Document 24: set()
# Document 25: set()
# Document 26: set()
# Document 27: set()
# Document 28: {'service', 'right', 'court'}
# Document 29: {'line', 'base'}
# Document 30: set()
# Document 31: set()
# Document 32: set()
# Document 33: {'back', 'line', 'service'}
# Document 34: {'center', 'mark'}
# Document 35: {'net'}
# Document 36: {'service', 'court', 'left'}
# Document 37: {'service', 'center'}
# Document 38: set()
# Document 39: {'fore', 'court'}
# Document 40: {'line'}
# Document 41: set()
# Document 42: {'ii'}
# Document 43: {'rules', 'tennis'}
# Document 44: {'singles', 'people', 'two', 'total', 'game'}
# Document 45: {'player', 'coin', 'choose', 'racket', 'winning', 'spin', 'may', 'toss'}
# Document 46: {'receiver', 'server'}
# Document 47: {'choose', 'side', 'sunny', 'net', 'want', 'hint', 'may', 'b'}
# Document 48: {'sun', 'side', 'facing'}
# Document 49: {'side', 'people', 'doubles', 'two', 'four', 'game', 'b'}
# Document 50: {'apply', 'singles', 'doubles', 'exceptions', 'rules'}
# Document 51: {'enclosing', 'alleys', 'used', 'outside', 'lines', 'boundary'}
# Document 52: set()
# Document 53: {'apply', 'service', 'fall', 'still', 'must', 'court', 'inside'}
# Document 54: {'order', 'service', 'first', 'game', 'c', 'partners', 'b'}
# Document 55: {'second', 'third', 'fourth', 'game', 'serves', 'c', 'b'}
# Document 56: {'order', 'maintained', 'set', 'etc', 'serves', 'throughout'}
# Document 57: {'set', 'two', 'games', 'consecutive', 'six', 'winning'}
# Document 58: {'games', 'five', 'team'}
# Document 59: set()
# Document 60: {'iii'}
# Document 61: {'service'}
# Document 62: {'delivery'}
# Document 63: {'center', 'mark', 'must', 'behind', 'server', 'inside', 'feet', 'baseline'}
# Document 64: {'singles', 'foot', 'called', 'sidelines', 'server', 'fault'}
# Document 65: {'loses', 'point'}
# Document 66: {'touches', 'strike', 'must', 'ball', 'air', 'ground', 'toss'}
# Document 67: {'diagonal', 'net', 'must', 'court', 'serve', 'across'}
# Document 68: {'right', 'every', 'start', 'game', 'court', 'shall'}
# Document 69: {'alternate', 'point', 'first', 'courts'}
# Document 70: {'fair', 'line', 'ball', 'striking'}
# Document 71: set()
# Document 72: {'chances', 'two', 'first', 'server', 'court', 'correct', 'serve', 'get'}
# Document 73: {'goof', 'fault', 'error', 'causes'}
# Document 74: {'way', 'receiver', 'score', 'ready', 'good', 'calling', 'may', 'serve'}
# Document 75: {'always', 'say', 'call', 'first', 'server', 'score', 'ready', 'serve'}
# Document 76: {'faults', 'b'}
# Document 77: {'line', 'fault', 'steeping', 'foot'}
# Document 78: {'service', 'anywhere', 'boundaries', 'diagonally', 'sent', 'ball', 'outside', 'opposite'}
# Document 79: {'net', 'court'}
# Document 80: {'strike', 'misses', 'server', 'ball', 'attempting'}
# Document 81: {'loses', 'faults', 'double', 'two', 'succession', 'server', 'called', 'fault'}
# Document 82: {'point'}
# Document 83: {'let', 'replays', 'c', 'point'}
# Document 84: {'net', 'service', 'falls', 'ball', 'court', 'tips', 'correct'}
# Document 85: {'served', 'ready', 'ball', 'receiver'}
# Document 86: {'interference', 'outside', 'following', 'play', 'serve'}
# Document 87: {'question', 'legal', 'play'}
# Document 88: {'let', 'replayed', 'circumstance', 'called', 'ball'}
# Document 89: {'iv'}
# Document 90: {'scoring'}
# Document 91: {'game'}
# Document 92: set()
# Document 93: {'love', 'nothing', 'zero'}
# Document 94: {'st', 'fifteen', 'point'}
# Document 95: set()
# Document 96: {'thirty', 'point', 'nd'}
# Document 97: set()
# Document 98: {'point', 'rd', 'forty'}
# Document 99: set()
# Document 100: {'player', 'two', 'points', 'pointgameprovided', 'ahead', 'team', 'one', 'th'}
# Document 101: {'score', 'equal', 'deuce', 'tie', 'b'}
# Document 102: set()
# Document 103: {'thereafter', 'score', 'called', 'deuce', 'tie'}
# Document 104: set()
# Document 105: {'wins', 'point', 'first', 'server', 'deuce', 'adin', 'advantage'}
# Document 106: set()
# Document 107: {'wins', 'receiver', 'point', 'first', 'adout', 'deuce', 'advantage'}
# Document 108: {'point'}
# Document 109: {'number', 'times', 'must', 'back', 'game', 'explanation', 'deuce', 'may', 'go'}
# Document 110: {'player', 'two', 'continue', 'ahead', 'one'}
# Document 111: {'example'}
# Document 112: {'player', 'points', 'two', 'receiver', 'server', 'three', 'b'}
# Document 113: {'score'}
# Document 114: {'point', 'earns', 'next', 'score', 'deuce', 'b'}
# Document 115: {'receiver', 'point', 'earns', 'next', 'score', 'c', 'adout', 'advantage', 'b'}
# Document 116: {'point', 'earns', 'next', 'score', 'deuce'}
# Document 117: {'two', 'points', 'receiver', 'earns', 'next', 'score', 'game', 'e', 'b'}
# Document 118: set()
# Document 119: {'v'}
# Document 120: {'changing', 'sides', 'court'}
# Document 121: {'sides', 'players', 'every', 'net', 'games', 'number', 'odd', 'change'}
# Document 122: {'ect'}
# Document 123: {'vi'}
# Document 124: {'set', 'games', 'first', 'team', 'win'}
# Document 125: set()
# Document 126: {'vi'}
# Document 127: {'match', 'set', 'unit', 'scoring', 'next', 'sets', 'best'}
# Document 128: set()
# Document 129: set()
# Document 130: set()
# Document 131: set()
# Document 132: set()
# Document 133: set()
# Document 134: {'terminology', 'tennis'}
# Document 135: set()
# Document 136: {'handed', 'player', 'side', 'hit', 'right', 'stroke', 'backhand', 'left', 'used', 'balls'}
# Document 137: {'handed', 'player', 'right', 'side', 'left'}
# Document 138: {'handed', 'player', 'right', 'hit', 'side', 'stroke', 'forehand', 'used', 'balls'}
# Document 139: {'handed', 'player', 'side', 'left'}
# Document 140: {'lands', 'arching', 'near', 'high', 'shot', 'lob', 'baseline'}
# Document 141: {'beginning', 'stroke', 'point', 'put', 'used', 'ball', 'play', 'serve'}
# Document 142: {'hit', 'stroke', 'bounced', 'used', 'volley', 'ball', 'air'}
# Document 143: {'forth', 'periods', 'hit', 'back', 'ball', 'long', 'rally', 'time'}
# Document 144: set()
# Document 145: {'two', 'racket', 'least', 'court', 'balls', 'equipment'}
# Document 146: set()
# Document 147: {'two', 'point', 'saves', 'etiquette', 'possession', 'thought', 'balls', 'time', 'servers', 'begin'}
# Document 148: {'keep', 'helps', 'faults', 'track', 'serve'}
# Document 149: set()
# Document 150: set()
# Document 151: {'part', 'head', 'racket', 'throat'}
# Document 152: {'includes', 'frame', 'strings'}
# Document 153: {'face', 'hitting', 'racket', 'surface'}
# Document 154: set()
# Document 155: set()
# Document 156: set()
# Document 157: set()
# Document 158: set()
# Document 159: set()
# Document 160: set()
# Document 161: set()
# Document 162: {'turned', 'racket', 'open', 'hitting', 'face'}
# Document 163: set()
# Document 164: set()
# Document 165: set()
# Document 166: set()
# Document 167: set()
# Document 168: set()
# Document 169: set()
# Document 170: set()
# Document 171: {'facing', 'upward', 'surface'}
# Document 172: set()
# Document 173: set()
# Document 174: set()
# Document 175: set()
# Document 176: set()
# Document 177: set()
# Document 178: set()
# Document 179: set()
# Document 180: {'closed', 'turned', 'face', 'racket'}
# Document 181: set()
# Document 182: set()
# Document 183: set()
# Document 184: set()
# Document 185: set()
# Document 186: set()
# Document 187: set()
# Document 188: set()
# Document 189: {'facing', 'downward', 'hitting', 'surface'}
# Document 190: set()
# Document 191: set()
# Document 192: set()
# Document 193: set()
# Document 194: set()
# Document 195: set()
# Document 196: set()
# Document 197: set()
# Document 198: {'racket', 'surface', 'hitting', 'flat', 'face', 'facing'}
# Document 199: set()
# Document 200: set()
# Document 201: set()
# Document 202: set()
# Document 203: set()
# Document 204: set()
# Document 205: set()
# Document 206: set()
# Document 207: {'net', 'perpendicular', 'ground'}
# Document 208: set()
# Document 209: set()
# Document 210: set()
# Document 211: set()
# Document 212: set()
# Document 213: set()
# Document 214: set()
# Document 215: set()
# Document 216: set()
# Document 217: set()
# Document 218: set()
# Document 219: set()
# Document 220: set()
# Document 221: set()
# Document 222: set()
# Document 223: set()
# Document 224: set()
# Document 225: set()
# Document 226: set()
# Document 227: set()
# Document 228: set()
# Document 229: set()
# Document 230: set()
# Document 231: set()
# Document 232: set()
# Document 233: set()
# Document 234: {'wooden', 'part', 'aluminum', 'throat'}
# Document 235: set()
# Document 236: set()
# Document 237: set()
# Document 238: set()
# Document 239: set()
# Document 240: set()
# Document 241: set()
# Document 242: set()
# Document 243: {'frame', 'head', 'racket'}
# Document 244: set()
# Document 245: set()
# Document 246: set()
# Document 247: set()
# Document 248: set()
# Document 249: set()
# Document 250: set()
# Document 251: set()
# Document 252: set()
# Document 253: set()
# Document 254: set()
# Document 255: set()
# Document 256: set()
# Document 257: {'wooden', 'racket', 'shaft', 'grip', 'handle'}
# Document 258: set()
# Document 259: set()
# Document 260: set()
# Document 261: set()
# Document 262: set()
# Document 263: set()
# Document 264: {'leather', 'covered', 'aluminum', 'gripped'}
# Document 265: set()
# Document 266: set()
# Document 267: set()
# Document 268: set()
# Document 269: set()
# Document 270: set()
# Document 271: {'hand'}
# Document 272: set()
# Document 273: {'top', 'racket', 'trim', 'small', 'stringing', 'bottom'}
# Document 274: {'strings', 'holding', 'place', 'main', 'head', 'purpose'}
# Document 275: set()
# Document 276: set()
# ####################################################################################################
# Document 1: {'lreccoling', 'pages'}
# Document 2: {'elra', 'bync', 'resource', 'language', 'cc', 'association', 'may'}
# Document 3: set()
# Document 4: {'analysis', 'nlp', 'emotion'}
# Document 5: {'trends', 'gaps', 'roadmap', 'future', 'directions'}
# Document 6: {'miriam', 'curry', 'flor', 'plazadelarco', 'alba'}
# Document 7: {'cercas', 'dirk', 'hovy', 'curry', 'amanda'}
# Document 8: {'milan', 'bocconi', 'department', 'italy', 'university', 'computing', 'sciences', 'milanlp'}
# Document 9: {'philosophy', 'leeds', 'history', 'university', 'religion', 'school', 'science'}
# Document 10: {'dirkhovyunibocconiit', 'florplaza', 'amandacercas'}
# Document 11: {'aacercascurryleedsacuk'}
# Document 12: {'abstract'}
# Document 13: {'emotions', 'field', 'emotion', 'growing', 'communication', 'ea', 'analysis', 'rapidly', 'central', 'consequently', 'aspect'}
# Document 14: {'processing', 'methods', 'direction', 'however', 'consensus', 'scope', 'nlp', 'language', 'natural'}
# Document 15: {'decade', 'publications', 'based', 'paper', 'conduct', 'relevant', 'thorough', 'last', 'nlp', 'review'}
# Document 16: {'tasks', 'address', 'questions', 'four', 'ea', 'nlp', 'defined', 'different', 'prominent'}
# Document 17: {'subjectivity', 'emotions', 'emotion', 'considered', 'frameworks', 'terms', 'modeled'}
# Document 18: {'trends', 'demographics', 'take', 'stock', 'primary', 'cultural', 'factors', 'nlp', 'applications', 'ea'}
# Document 19: {'tasks', 'emotion', 'four', 'existing', 'used', 'frameworks', 'ea', 'applications', 'discuss', 'methods', 'datasets'}
# Document 20: {'variation', 'emotions', 'aspects', 'lacunae', 'account', 'absence', 'cultural', 'demographic'}
# Document 21: {'fit', 'emotion', 'assumes', 'manner', 'universally', 'experienced', 'instead', 'perceived', 'poor'}
# Document 22: {'gap', 'main', 'emotion', 'two', 'categories', 'lack', 'theories', 'standardized', 'terminology', 'hinders', 'task', 'ea'}
# Document 23: {'goals', 'identification', 'research', 'interdisciplinary', 'comparison', 'absence', 'ea', 'isolates', 'future'}
# Document 24: {'enable', 'fields', 'work', 'focused', 'insights', 'research', 'approach', 'modeling', 'ea', 'holistic'}
# Document 25: {'emotions', 'nlp'}
# Document 26: {'trends', 'gaps', 'emotion', 'survey', 'keywords', 'analysis'}
# Document 27: set()
# Document 28: {'introduction'}
# Document 29: {'every', 'experience', 'perfume', 'emotions'}
# Document 30: {'key', 'role', 'playing', 'human', 'teraction', 'cognition'}
# Document 31: {'recent', 'decades', 'research', 'relationships'}
# Document 32: {'fields', 'become', 'numerous', 'emotion', 'popular'}
# Document 33: {'sci', 'humanities', 'social', 'including', 'psychology'}
# Document 34: {'processing', 'inter', 'nlp', 'language', 'ences', 'natural'}
# Document 35: {'anal', 'emotion', 'mostly', 'translates', 'est'}
# Document 36: {'notable', 'ysis', 'ea', 'growth', 'whose'}
# Document 37: {'mihalcea', 'strapparava', 'mo', 'since'}
# Document 38: {'plazadel', 'klinger', 'hammad', 'al', 'et'}
# Document 39: {'nissim', 'mohammad', 'arco', 'al', 'et'}
# Document 40: {'al', 'plazadelarco', 'et', 'b', 'barnes'}
# Document 41: set()
# Document 42: {'papers', 'acl', 'survey'}
# Document 43: {'address', 'questions', 'ea', 'four'}
# Document 44: {'tasks', 'promi', 'defined', 'nlp'}
# Document 45: {'frameworks', 'nent', 'emotions', 'emotion'}
# Document 46: {'subjectivity', 'consid', 'emotions', 'modeled'}
# Document 47: {'demographics', 'ered', 'cultural', 'factors', 'terms'}
# Document 48: {'ea', 'primary', 'applications', 'nlp'}
# Document 49: {'lack', 'find', 'consensus', 'scope', 'terms'}
# Document 50: {'direction', 'studies', 'current', 'methods'}
# Document 51: {'concerns', 'important', 'three', 'raises'}
# Document 52: {'complete', 'main', 'note', 'goal', 'snapshot'}
# Document 53: {'field', 'rather', 'ea', 'specific', 'method', 'snapshot'}
# Document 54: {'ological', 'issues', 'ea', 'nlp', 'within'}
# Document 55: {'selection', 'criteria', 'see', 'section'}
# Document 56: {'scene', 'movie'}
# Document 57: {'walk', 'lovers', 'two', 'hand'}
# Document 58: {'sunset', 'hand'}
# Document 59: {'evoked', 'emotion'}
# Document 60: {'nostalgia'}
# Document 61: {'excitement'}
# Document 62: {'age'}
# Document 63: {'age'}
# Document 64: {'variation', 'figure', 'emotion', 'based', 'annotation'}
# Document 65: {'demo', 'distinct', 'demographics', 'annotators'}
# Document 66: {'year', 'graphic', 'yearold', 'male', 'profiles'}
# Document 67: {'varying', 'old', 'interpretations', 'male', 'emo', 'exhibit'}
# Document 68: {'evoked', 'tions'}
# Document 69: {'absence', 'cultural', 'demographic'}
# Document 70: {'variation', 'account', 'pects'}
# Document 71: {'presented', 'perceived', 'emotions'}
# Document 72: {'experienced', 'sumes', 'universally'}
# Document 73: {'manner', 'general', 'en', 'lack'}
# Document 74: {'recent', 'gagement', 'work', 'emotions'}
# Document 75: {'camp', 'gendered', 'judd', 'racialized'}
# Document 76: {'words', 'bell', 'etc', 'produces'}
# Document 77: {'anno', 'figure', 'data', 'see', 'matters'}
# Document 78: {'tates'}
# Document 79: {'emotion', 'fit', 'categories', 'poor', 'task'}
# Document 80: {'poses', 'significant', 'commonly', 'challenge'}
# Document 81: {'emotion', 'categories', 'used', 'predefined', 'may', 'ad'}
# Document 82: set()
# Document 83: set()
# Document 84: {'required', 'equately', 'capture', 'nuances'}
# Document 85: {'downstream', 'task'}
# Document 86: {'nomenclature', 'common', 'systematic', 'lack'}
# Document 87: {'limits', 'obscures', 'gaps', 'comparison', 'ea'}
# Document 88: {'therefore', 'example', 'future', 'objectives'}
# Document 89: {'shows', 'prediction', 'synonymous', 'survey'}
# Document 90: {'nlp', 'areas', 'classification'}
# Document 91: {'tasks', 'two', 'used', 'distinct', 'terms'}
# Document 92: {'dearth', 'interdisciplinary', 'research', 'means'}
# Document 93: {'progress', 'inform', 'fields', 'ea'}
# Document 94: {'area', 'de', 'main', 'problematic', 'task', 'level'}
# Document 95: {'work', 'still', 'predominantly', 'nlp', 'relies', 'sign'}
# Document 96: {'paul', 'ek', 'ekman', 'friesen'}
# Document 97: {'work', 'addressed', 'question', 'mans', 'basic', 'emo'}
# Document 98: {'provide', 'account', 'comprehensive', 'tions'}
# Document 99: {'emo', 'define', 'emotions', 'helpful'}
# Document 100: {'tions', 'categories', 'provides', 'theory', 'thus'}
# Document 101: {'useful', 'oversimplified', 'broad'}
# Document 102: {'tasks', 'de', 'languages', 'bruyne', 'across'}
# Document 103: {'reallife', 'crucial', 'emotions', 'applications'}
# Document 104: {'diverse', 'emotion', 'paper', 'also', 'explores', 'range'}
# Document 105: {'focusing', 'recog', 'emotion', 'applications', 'dialogue'}
# Document 106: {'used', 'nition', 'widely', 'prominent'}
# Document 107: {'tailored', 'used', 'pur', 'analyze', 'widely', 'datasets'}
# Document 108: {'key', 'characteristics', 'pose', 'highlighting'}
# Document 109: {'field', 'previous', 'focuses', 'unlike', 'surveys'}
# Document 110: {'gaps', 'questions', 'revealing', 'unexplored', 'critical'}
# Document 111: {'field', 'attention', 'ea', 'community', 'require'}
# Document 112: {'connect', 'aim', 'focused', 'gaps', 'fostering'}
# Document 113: {'nuanced', 'emotion', 'search', 'modeling', 'nlp'}
# Document 114: {'suggestions', 'conclude', 'recommendations'}
# Document 115: {'work', 'future'}
# Document 116: set()
# Document 117: {'related', 'work'}
# Document 118: {'considerable', 'research', 'attracted', 'interest', 'ea'}
# Document 119: {'provide', 'surveys', 'various', 'comprehensive', 'overview'}
# Document 120: {'canales', 'martnez', 'field', 'state'}
# Document 121: {'barco', 'yadollahi', 'garciagarcia', 'al', 'et'}
# Document 122: {'klinger', 'al', 'kim', 'mntyl', 'et'}
# Document 123: {'saxena', 'et', 'acheampong', 'al'}
# Document 124: {'surveys', 'recent', 'murthy', 'kumar'}
# Document 125: {'tomar', 'kusal', 'al', 'singh', 'et', 'b'}
# Document 126: {'identification', 'focused', 'datasets', 'primarily'}
# Document 127: {'detection', 'models', 'techniques', 'computing', 'affective'}
# Document 128: {'appli', 'textual', 'visual', 'etc', 'modalities', 'vocal'}
# Document 129: {'surveys', 'literature', 'ac', 'cations'}
# Document 130: {'certain', 'knowledge', 'ea', 'limitations'}
# Document 131: {'imbalance', 'scarcity', 'labeled', 'data', 'datasets'}
# Document 132: {'nlp', 'english', 'performance', 'dominance'}
# Document 133: {'address', 'methods', 'signifi'}
# Document 134: {'gaps', 'cant', 'specifically', 'disregard', 'discuss'}
# Document 135: {'anal', 'demographic', 'significance', 'factors'}
# Document 136: {'work', 'sailunaz', 'ysis', 'mention', 'brief'}
# Document 137: {'collecting', 'al', 'aggregation', 'et', 'methods'}
# Document 138: {'inter', 'importance', 'annotator', 'perspectives'}
# Document 139: {'disciplinarity'}
# Document 140: {'conducted', 'comprehensive', 'mohammad'}
# Document 141: {'liter', 'ethics', 'emotion', 'recognition', 'analysis', 'ai'}
# Document 142: {'rele', 'ature', 'considerations', 'synthesising', 'ethical'}
# Document 143: {'work', 'emotion', 'recognition', 'pro', 'vant', 'automatic'}
# Document 144: {'ethics', 'valuable', 'consider', 'vides', 'pointers'}
# Document 145: {'topics', 'consid', 'crucial', 'covered'}
# Document 146: {'demographic', 'eration', 'modeling', 'factors'}
# Document 147: {'dataset', 'perspectives', 'annotators', 'creation'}
# Document 148: {'identified', 'gaps', 'demonstrate', 'inherent'}
# Document 149: {'advancements', 'ethics', 'connection'}
# Document 150: {'ea', 'nlp'}
# Document 151: set()
# Document 152: {'analysis', 'nlp', 'emotion', 'survey'}
# Document 153: {'section', 'present', 'papers', 'survey'}
# Document 154: {'ensure', 'anthology', 'acl', 'compre'}
# Document 155: {'focused', 'studies', 'hensive', 'ea', 'selection'}
# Document 156: {'titles', 'papers', 'include', 'whose', 'abstracts', 'identifying'}
# Document 157: {'tasks', 'field', 'keywords', 'ea', 'nlp', 'associated'}
# Document 158: {'analysis', 'prediction', 'emotion'}
# Document 159: {'classification', 'emo', 'detection', 'emotion'}
# Document 160: {'emotion', 'recognition', 'polarity', 'tion', 'classification'}
# Document 161: {'cause', 'detection', 'emotion', 'increased', 'ea'}
# Document 162: {'doubled', 'time', 'frequency', 'horizon'}
# Document 163: {'published', 'consider', 'years', 'papers', 'last', 'ten'}
# Document 164: {'removed', 'duplicates', 'shared', 'papers'}
# Document 165: {'ap', 'studies', 'participants', 'task', 'resulting'}
# Document 166: {'inclusion', 'ensure', 'plied', 'additional', 'criteria'}
# Document 167: {'influential', 'works', 'relevant', 'survey', 'specifi'}
# Document 168: {'citation', 'count', 'cally', 'papers', 'opted'}
# Document 169: {'scholar', 'median', 'average', 'semantic', 'surpassing'}
# Document 170: {'adjusted', 'selfcitations', 'however', 'excluding'}
# Document 171: {'citation', 'threshold', 'pub', 'papers', 'least'}
# Document 172: {'current', 'lished', 'year', 'last', 'following'}
# Document 173: {'set', 'process', 'contains', 'analysis', 'selection', 'final'}
# Document 174: {'published', 'among', 'papers'}
# Document 175: {'workshops', 'conferences', 'findings', 'main'}
# Document 176: {'col', 'paper', 'venues'}
# Document 177: {'lected', 'emotions', 'used', 'information', 'following'}
# Document 178: {'model', 'language', 'type', 'emotion'}
# Document 179: {'presence', 'data', 'lexicon', 'dataset', 'source'}
# Document 180: {'multimodality', 'yes', 'nomenclature', 'used'}
# Document 181: {'cre', 'paper', 'focuses', 'dataset', 'applications'}
# Document 182: {'whether', 'also', 'determined', 'ation', 'annotators'}
# Document 183: {'considered', 'demographics'}
# Document 184: {'provides', 'papers', 'figure', 'overview'}
# Document 185: {'clear', 'trend', 'keyword', 'year'}
# Document 186: {'number', 'papers'}
# Document 187: {'marking', 'significant', 'increase', 'appearance'}
# Document 188: {'september', 'acl', 'time', 'study'}
# Document 189: {'contained', 'anthology', 'including', 'papers'}
# Document 190: {'like', 'nonacl', 'events', 'lrec'}
# Document 191: {'rel', 'acknowledge', 'existence'}
# Document 192: {'evant', 'papers', 'ea', 'terms', 'core', 'pertinent'}
# Document 193: {'terms', 'use', 'questions', 'predominantly'}
# Document 194: set()
# Document 195: {'provide'}
# Document 196: set()
# Document 197: {'survey'}
# Document 198: {'data'}
# Document 199: set()
# Document 200: {'github'}
# Document 201: {'httpsgithubcommilanlprocemotion'}
# Document 202: {'analysissurvey'}
# Document 203: set()
# Document 204: set()
# Document 205: {'distribution', 'considered', 'papers', 'figure'}
# Document 206: {'keyword', 'year', 'survey'}
# Document 207: {'jump', 'indicates', 'growing', 'studies', 'interest', 'ea'}
# Document 208: {'five', 'last', 'field', 'years'}
# Document 209: set()
# Document 210: {'nomenclature'}
# Document 211: {'figure', 'also', 'provides', 'com', 'overview'}
# Document 212: {'tasks', 'describe', 'monly', 'term', 'used', 'ea', 'terms'}
# Document 213: {'recognition', 'fre', 'stands', 'emotion'}
# Document 214: {'emotion', 'followed', 'analy', 'quently', 'used'}
# Document 215: {'classification', 'sis', 'emotion'}
# Document 216: {'prediction', 'detection', 'emotion'}
# Document 217: {'cause', 'detection', 'emotion', 'used', 'least'}
# Document 218: {'terms'}
# Document 219: {'analysis', 'however', 'note'}
# Document 220: {'used', 'terms', 'figure', 'isolation'}
# Document 221: {'pairs', 'used', 'prevalent', 'terms', 'highlights'}
# Document 222: {'tasks', 'papers', 'refer', 'different', 'across'}
# Document 223: {'frequent', 'pair', 'classificationrecognition'}
# Document 224: {'fol', 'interchangeably', 'papers', 'used', 'across'}
# Document 225: {'classificationanalysis', 'lowed', 'classification'}
# Document 226: {'variation', 'detection', 'stan', 'indicates', 'lack'}
# Document 227: {'dardized', 'terminology', 'ea', 'tasks'}
# Document 228: {'uniformity', 'given', 'definitions', 'lack', 'providing'}
# Document 229: {'challenging', 'chosen', 'ea', 'term'}
# Document 230: {'demarcates', 'category', 'broad', 'emotion'}
# Document 231: {'related', 'nlp', 'distinguished', 'tasks'}
# Document 232: {'analysis', 'opinion', 'sentiment', 'mining'}
# Document 233: {'analysis', 'literature', 'sentiment', 'consensus'}
# Document 234: {'someone', 'refers', 'whether', 'expresses', 'identifying'}
# Document 235: {'yadollahi', 'et', 'al', 'attitude', 'positive', 'negative'}
# Document 236: {'sentiments', 'differentiated', 'emotions'}
# Document 237: {'munezero', 'duration', 'experienced'}
# Document 238: {'primarily', 'al', 'ea', 'interested', 'contrast', 'et'}
# Document 239: {'specific', 'anger', 'emotions', 'joy'}
# Document 240: {'emotion', 'literature', 'reviewed', 'task', 'recogni'}
# Document 241: {'tiondetectionclassificationprediction', 'refers'}
# Document 242: {'emotion', 'specific', 'goal', 'expressed', 'identifying'}
# Document 243: {'author', 'set', 'particular', 'utterance', 'utter'}
# Document 244: {'chatterjee', 'mohammad', 'al', 'ances', 'et'}
# Document 245: {'cases', 'task', 'refers', 'identi'}
# Document 246: {'cause', 'emotions', 'fying', 'context', 'broader'}
# Document 247: {'others', 'speakers', 'affect', 'example', 'emo'}
# Document 248: {'conversation', 'zhan', 'liu', 'state', 'al', 'tional', 'et'}
# Document 249: {'section', 'al', 'issues', 'discuss', 'et'}
# Document 250: {'arise', 'terminology', 'consistent', 'lack'}
# Document 251: set()
# Document 252: {'frameworks', 'models', 'emotion'}
# Document 253: {'several', 'conceptual', 'models', 'psychologists'}
# Document 254: {'neuroscientists', 'emerged', 'categorize'}
# Document 255: {'emotions', 'models', 'notably', 'three', 'terpret', 'prominent'}
# Document 256: {'stand', 'categorical', 'model', 'discrete'}
# Document 257: {'model', 'componential', 'dimensional'}
# Document 258: {'described', 'following'}
# Document 259: {'categorial', 'model', 'emotions', 'discrete'}
# Document 260: {'classes', 'distinct', 'categorized', 'cate'}
# Document 261: {'model', 'gories', 'treated', 'emotion'}
# Document 262: {'separate', 'independent', 'others'}
# Document 263: {'model', 'frameworks', 'includes', 'wellknown'}
# Document 264: {'model', 'ekmans', 'ekman', 'friesen'}
# Document 265: {'emotions', 'anger', 'basic', 'consisting', 'six'}
# Document 266: {'sadness', 'sur', 'joy', 'fear', 'disgust'}
# Document 267: {'model', 'plutchik', 'plutchiks', 'prise'}
# Document 268: {'emotions', 'primary', 'encompasses', 'eight'}
# Document 269: {'disgust', 'anger', 'fear', 'anticipation'}
# Document 270: {'trust', 'sadness', 'surprise', 'joy'}
# Document 271: {'model', 'dimensional'}
# Document 272: {'previous', 'unlike'}
# Document 273: {'dimensional', 'emotions', 'models', 'model', 'view'}
# Document 274: {'enti', 'interconnected', 'rather', 'independent'}
# Document 275: {'model', 'ties', 'emotions', 'acknowledges'}
# Document 276: {'represented', 'vary', 'intensity'}
# Document 277: {'dimensions', 'emo', 'instance', 'along', 'different'}
# Document 278: {'names', 'vector', 'located', 'tion', 'spaces'}
# Document 279: {'valence', 'consider', 'arousal', 'dom', 'affect'}
# Document 280: {'vad', 'inance', 'mehrabian', 'russell'}
# Document 281: {'componential'}
# Document 282: {'model'}
# Document 283: set()
# Document 284: {'componen'}
# Document 285: {'model', 'appraisal', 'theory', 'tial', 'comprised'}
# Document 286: {'scherer', 'lazarus', 'em'}
# Document 287: {'emotions', 'influenced', 'phasizes'}
# Document 288: {'appraisal', 'subjective', 'evaluation', 'persons'}
# Document 289: {'experience', 'situation', 'factors'}
# Document 290: {'pleasant', 'certainty', 'responsibility'}
# Document 291: {'sig', 'ness', 'attention', 'play', 'control'}
# Document 292: {'role', 'nificant', 'influencing', 'individuals', 'emo'}
# Document 293: {'situation', 'tional', 'particular', 'responses'}
# Document 294: {'experience', 'ellsworth', 'smith'}
# Document 295: {'clear', 'prevalence', 'dis', 'reveals', 'analysis'}
# Document 296: {'models', 'literature', 'indicating', 'crete', 'conceptual'}
# Document 297: {'emotions', 'classifying', 'distinct', 'interest', 'strong'}
# Document 298: {'emotion', 'inde', 'treating', 'categories'}
# Document 299: {'pendent', 'standard', 'entity', 'line', 'supervised'}
# Document 300: {'learning', 'objectives', 'use', 'papers', 'di', 'however'}
# Document 301: {'models', 'even', 'smaller', 'proportion', 'mensional'}
# Document 302: {'componential', 'explore', 'models'}
# Document 303: set()
# Document 304: set()
# Document 305: {'tasks', 'common', 'figure', 'literature', 'pairs', 'nomenclature', 'used', 'ea'}
# Document 306: {'common', 'figure', 'emotion', 'categories', 'used'}
# Document 307: {'literature', 'ea'}
# Document 308: {'categorical', 'research', 'papers', 'emo', 'discrete'}
# Document 309: {'rely', 'models', 'commonly', 'theories', 'tion', 'different', 'upon'}
# Document 310: {'influential', 'ekman', 'model', 'ek', 'theory'}
# Document 311: {'plutchik', 'man', 'followed', 'friesen'}
# Document 312: {'model', 'consid', 'studies', 'plutchik'}
# Document 313: {'ortony', 'ered', 'turner', 'list', 'turne'}
# Document 314: {'ortony', 'collins', 'model', 'al', 'clore', 'et'}
# Document 315: {'dimensional', 'models', 'mapping', 'used', 'studies'}
# Document 316: {'approach', 'emotion', 'categories', 'di', 'associate'}
# Document 317: {'bagher', 'zadeh', 'mensions', 'al', 'instance', 'et'}
# Document 318: {'ekman', 'conducted', 'mapping', 'data', 'annotating'}
# Document 319: {'scale', 'likert', 'emotions', 'values'}
# Document 320: {'signed', 'emo', 'presence', 'represent'}
# Document 321: {'tions', 'introduced', 'al', 'et', 'framework', 'park'}
# Document 322: {'obtained', 'vad', 'scores', 'leverages', 'emo'}
# Document 323: {'vad', 'scores', 'acquire', 'lexicon', 'tion', 'sentences'}
# Document 324: {'categorical', 'emotions', 'recently', 'labeled'}
# Document 325: {'componential', 'gained', 'attention', 'models'}
# Document 326: {'field', 'introduced', 'al', 'et', 'hofmann'}
# Document 327: {'established', 'event', 'de', 'task', 'annotation'}
# Document 328: {'dimensions', 'linked', 'seven', 'appraisal', 'scriptions'}
# Document 329: {'ellsworth', 'smith', 'stranisci', 'al', 'et'}
# Document 330: {'roseman', 'relied', 'model', 'appraisal', 'rosemans'}
# Document 331: {'social', 'corpus', 'media', 'posts', 'annotate'}
# Document 332: {'built', 'troiano', 'al', 'recently', 'corpus', 'et'}
# Document 333: {'emotiontriggering', 'described', 'people', 'events'}
# Document 334: {'appraisals', 'subsequently', 'readers'}
# Document 335: {'reconstruct', 'appraisals', 'emotions', 'asked'}
# Document 336: {'text', 'appraisal', 'theory', 'provide', 'thorough'}
# Document 337: {'emotion', 'suitability', 'analysis', 'textbased', 'overview'}
# Document 338: {'shows', 'appraisals', 'additionally', 'assessment'}
# Document 339: {'approach', 'computational', 'offer', 'alternative', 'ea'}
# Document 340: {'emotion', 'enhance', 'text', 'using', 'categorization'}
# Document 341: {'joint', 'models'}
# Document 342: {'provides', 'fre', 'figure', 'overview'}
# Document 343: {'due', 'emotion', 'literature', 'categories', 'quent'}
# Document 344: {'widespread', 'ekman', 'model', 'use', 'ekmans'}
# Document 345: {'observed', 'emotions', 'prevalent', 'friesen'}
# Document 346: {'sadness', 'anger', 'joy', 'fear', 'disgust'}
# Document 347: {'plutchiks', 'model', 'additionally', 'surprise'}
# Document 348: {'used', 'highlights', 'frequency', 'second'}
# Document 349: {'range', 'trust', 'however', 'anticipation'}
# Document 350: {'emotions', 'less', 'comparatively', 'atten', 'receives'}
# Document 351: {'op', 'excitement', 'tion', 'anxiety', 'include'}
# Document 352: {'timism', 'guilt', 'love', 'shame', 'pessimism'}
# Document 353: set()
# Document 354: {'data'}
# Document 355: {'provide', 'section', 'overview'}
# Document 356: {'used', 'various', 'extensively', 'datasets'}
# Document 357: {'developed', 'recently', 'studies', 'ea', 'datasets'}
# Document 358: {'analysis', 'identified', 'papers'}
# Document 359: {'summary', 'created', 'gives', 'list', 'dataset', 'table'}
# Document 360: {'key', 'showcasing', 'datasets'}
# Document 361: {'characteristics', 'scheme', 'mul', 'language', 'annotation'}
# Document 362: {'size', 'timodality', 'source'}
# Document 363: {'found', 'studies', 'ea', 'datasets'}
# Document 364: {'recognition', 'focused', 'conversa', 'emotion'}
# Document 365: set()
# Document 366: set()
# Document 367: {'dataset'}
# Document 368: {'annotation'}
# Document 369: {'lang'}
# Document 370: {'source'}
# Document 371: {'size'}
# Document 372: {'kawahara', 'ide', 'idedialog'}
# Document 373: set()
# Document 374: {'p'}
# Document 375: {'ja'}
# Document 376: {'dialogues', 'twitter'}
# Document 377: set()
# Document 378: {'zhao', 'med', 'et', 'al'}
# Document 379: {'neutral', 'e'}
# Document 380: {'cn'}
# Document 381: {'tv', 'dialogues'}
# Document 382: set()
# Document 383: {'al', 'et', 'jaiswal', 'muse'}
# Document 384: {'sad'}
# Document 385: {'anger'}
# Document 386: {'contentment'}
# Document 387: {'amusement', 'neutral'}
# Document 388: {'en'}
# Document 389: {'recordings'}
# Document 390: {'speak'}
# Document 391: {'ers'}
# Document 392: {'zahiri', 'meld', 'choi', 'po'}
# Document 393: {'ria', 'et', 'al'}
# Document 394: {'neutral', 'e'}
# Document 395: {'en'}
# Document 396: {'dialogues', 'movie'}
# Document 397: set()
# Document 398: {'li', 'al', 'dailydialog', 'et'}
# Document 399: {'e'}
# Document 400: {'en'}
# Document 401: {'dialogues', 'movie'}
# Document 402: set()
# Document 403: {'emorynlp'}
# Document 404: {'zahiri'}
# Document 405: set()
# Document 406: {'choi'}
# Document 407: set()
# Document 408: {'neutral', 'e'}
# Document 409: {'en'}
# Document 410: {'tv', 'dialogues', 'show'}
# Document 411: set()
# Document 412: {'al', 'iemocap', 'et', 'busso'}
# Document 413: {'anger', 'happiness', 'sadness'}
# Document 414: {'neutral', 'frustration'}
# Document 415: {'en'}
# Document 416: {'dyadic', 'interactions'}
# Document 417: set()
# Document 418: {'al', 'ngo', 'studemo', 'et'}
# Document 419: {'categories', 'emotion'}
# Document 420: {'en'}
# Document 421: {'reviews', 'customer'}
# Document 422: set()
# Document 423: {'red', 'al', 'ciobotaru', 'v', 'et'}
# ...
# Document 1518: {'muresan', 'elsbeth', 'turcan', 'smaranda', 'kathleen'}
# Document 1519: {'emotioninfused', 'mckeown', 'models'}
# Document 1520: {'psychological', 'stress', 'detection', 'explainable'}
# Document 1521: {'conference', 'north', 'proceedings'}
# Document 1522: {'compu', 'chapter', 'association', 'american'}
# Document 1523: {'linguistics', 'technolo', 'tational', 'human', 'language'}
# Document 1524: {'online', 'gies', 'association', 'pages'}
# Document 1525: {'linguistics', 'computational'}
# Document 1526: {'turner', 'jonathan', 'human', 'origins'}
# Document 1527: {'evolution', 'inquiry', 'sociological', 'emotions'}
# Document 1528: {'press', 'human', 'university', 'affect', 'stanford'}
# Document 1529: {'os', 'yadollahi', 'gholipour', 'ali', 'shahraki', 'ameneh'}
# Document 1530: {'zaiane', 'text', 'current', 'r', 'state', 'mar', 'sen'}
# Document 1531: {'emotion', 'mining', 'analysis', 'opinion', 'timent'}
# Document 1532: {'computing', 'surveys', 'acm'}
# Document 1533: {'finlayson', 'samira', 'systematic', 'mark', 'zad'}
# Document 1534: {'framework', 'emo', 'unsupervised', 'evaluation'}
# Document 1535: {'recognition', 'text', 'proceedings', 'tion', 'narrative'}
# Document 1536: {'workshop', 'narrative', 'first', 'joint'}
# Document 1537: {'storylines', 'standing', 'events', 'pages'}
# Document 1538: {'online', 'linguis', 'association', 'computational'}
# Document 1539: {'tics'}
# Document 1540: set()
# Document 1541: set()
# Document 1542: {'emotion', 'zahiri', 'sayyed', 'choi', 'jinho'}
# Document 1543: {'show', 'detection', 'transcripts', 'tv', 'sequence'}
# Document 1544: {'based', 'convolutional', 'aaai', 'neural', 'networks'}
# Document 1545: {'workshops'}
# Document 1546: {'sosea', 'zhan', 'hongli', 'cornelia', 'tiberiu', 'caragea'}
# Document 1547: {'junyi', 'feel', 'jessy', 'li', 'way'}
# Document 1548: {'emotions', 'social', 'summarizing', 'media', 'triggers'}
# Document 1549: {'posts', 'conference', 'proceedings'}
# Document 1550: {'empirical', 'pro', 'methods', 'language', 'natural'}
# Document 1551: {'abu', 'cessing', 'dhabi', 'united', 'pages'}
# Document 1552: {'emirates', 'association', 'arab', 'computational'}
# Document 1553: {'linguistics'}
# Document 1554: {'zhao', 'tenggan', 'jinming', 'jingwen', 'hu', 'zhang'}
# Document 1555: {'jin', 'qin', 'xinchao', 'liu', 'yuchen', 'wang', 'haizhou'}
# Document 1556: {'multiscene', 'multimodal', 'med', 'li', 'multi'}
# Document 1557: {'dialogue', 'database', 'label', 'emotional', 'proceed'}
# Document 1558: {'ings', 'annual', 'meeting', 'associ', 'th'}
# Document 1559: {'volume', 'linguistics', 'ation', 'computational'}
# Document 1560: {'papers', 'ireland', 'long', 'pages', 'dublin'}
# Document 1561: {'linguistics', 'association', 'computational'}
# Document 1562: {'chunyan', 'di', 'peixiang', 'zhong', 'wang', 'miao'}
# Document 1563: {'transformer', 'knowledgeenriched', 'emo'}
# Document 1564: {'textual', 'detection', 'pro', 'conversations', 'tion'}
# Document 1565: {'ceedings', 'empirical', 'conference'}
# Document 1566: {'natural', 'language', 'processing', 'methods'}
# Document 1567: {'international', 'conference', 'joint', 'th', 'natural'}
# Document 1568: {'language', 'pages', 'emnlpijcnlp', 'processing'}
# Document 1569: {'kong', 'china', 'association', 'hong'}
# Document 1570: {'linguistics', 'computational'}
# Document 1571: set()
# ####################################################################################################
# Document 1: {'lots', 'useful', 'see', 'information', 'helpsheet', 'wwwntuacukwellbeing'}
# Document 2: set()
# Document 3: set()
# Document 4: {'relationships'}
# Document 5: set()
# Document 6: {'introduction'}
# Document 7: set()
# Document 8: {'friends', 'relationships', 'whether', 'family', 'partner', 'intimate'}
# Document 9: {'love', 'great', 'pleasure', 'excitement', 'however', 'support', 'source'}
# Document 10: {'grief', 'anger', 'also', 'wrong', 'issue', 'go', 'made', 'anguish', 'source'}
# Document 11: {'people', 'students', 'relevant', 'university', 'fact'}
# Document 12: {'make', 'personal', 'sure', 'feel', 'less', 'period', 'want', 'change'}
# Document 13: {'expect', 'react', 'others'}
# Document 14: set()
# Document 15: {'makes', 'looked', 'work', 'relationships', 'successfully', 'researchers'}
# Document 16: {'relationships', 'whether', 'friendships', 'family', 'come', 'partnerships', 'tend'}
# Document 17: {'things'}
# Document 18: set()
# Document 19: {'acceptance', 'difference'}
# Document 20: {'people', 'relationships', 'try', 'force', 'exactly', 'successful'}
# Document 21: {'like', 'work', 'differences', 'accept'}
# Document 22: set()
# Document 23: {'boundaries', 'capacity'}
# Document 24: {'people', 'aware', 'point', 'person', 'stop'}
# Document 25: {'unrealistic', 'others', 'solve', 'begins', 'expect', 'problems'}
# Document 26: {'needs', 'meet'}
# Document 27: set()
# Document 28: {'mainly', 'present', 'operating'}
# Document 29: {'picking', 'events', 'relationships', 'focus', 'either', 'past', 'repeatedly'}
# Document 30: {'based', 'else', 'hope', 'things', 'better', 'tomorrow'}
# Document 31: {'wrong', 'tend', 'go'}
# Document 32: set()
# Document 33: {'choice', 'individual', 'respect'}
# Document 34: {'right', 'person', 'direction', 'accepted', 'decide'}
# Document 35: {'relationship', 'follow', 'adapts', 'life'}
# Document 36: set()
# Document 37: {'skill', 'negotiating'}
# Document 38: {'decided', 'family', 'individual', 'want', 'couple'}
# Document 39: {'goals', 'work', 'able', 'fair', 'different', 'fulfil', 'way'}
# Document 40: set()
# Document 41: {'sharing', 'feelings', 'positive'}
# Document 42: {'sexual', 'also', 'however', 'couple', 'may', 'intimacy'}
# Document 43: {'pleasantness', 'kindness', 'family'}
# Document 44: set()
# Document 45: {'skill', 'might', 'requires', 'quite', 'lot', 'relationship', 'individual'}
# Document 46: {'attachment', 'concluded', 'research', 'consider', 'comforting', 'john', 'bowlby'}
# Document 47: {'beings', 'form', 'social', 'know', 'innately', 'human', 'instinctively', 'tend'}
# Document 48: {'others', 'attachments', 'arise', 'relationship', 'problems', 'close', 'often'}
# Document 49: {'lost', 'touch', 'instinctive', 'learned', 'good', 'never'}
# Document 50: {'sense', 'become', 'relationships', 'overanxious'}
# Document 51: set()
# Document 52: {'make', 'relationships', 'touch', 'successful', 'ability', 'may'}
# Document 53: {'ever', 'seem', 'people', 'able', 'doubt', 'however', 'long', 'may'}
# Document 54: {'mind', 'skills', 'put', 'recover'}
# Document 55: set()
# Document 56: {'work', 'much', 'person', 'start', 'relationship', 'improving', 'individual', 'one'}
# Document 57: {'reasoned', 'clear', 'want', 'consistent'}
# Document 58: {'basis', 'whole', 'put', 'relationship', 'ask', 'different', 'begin'}
# Document 59: set()
# Document 60: set()
# Document 61: set()
# Document 62: set()
# Document 63: set()
# Document 64: {'dealing', 'problems', 'family'}
# Document 65: set()
# Document 66: {'people', 'might', 'involved', 'lot', 'family', 'also', 'problems', 'difficult'}
# Document 67: {'looking', 'us', 'objectively', 'families', 'bit', 'used', 'however'}
# Document 68: {'heat', 'take', 'lot', 'situations', 'analysis', 'reflection', 'difficult'}
# Document 69: set()
# Document 70: {'found', 'disagreement', 'something', 'family'}
# Document 71: set()
# Document 72: {'try', 'objectively', 'trying', 'think', 'give', 'achieve'}
# Document 73: {'behaviour', 'motives', 'doubt', 'benefit', 'best', 'attribute'}
# Document 74: {'make', 'might', 'point', 'realise', 'wrong', 'thing', 'youre', 'want'}
# Document 75: {'withdrawalstop', 'lets', 'thereconsider', 'apologising', 'strategic', 'however', 'assume'}
# Document 76: {'end', 'know', 'convinced', 'bit'}
# Document 77: {'back', 'evidence'}
# Document 78: set()
# Document 79: {'family', 'disagreeing', 'probably', 'think'}
# Document 80: {'understand', 'maybe', 'dont', 'reason', 'one', 'plan'}
# Document 81: {'maybe', 'course', 'decided', 'worries', 'action', 'anxieties'}
# Document 82: {'make', 'effort', 'real', 'even', 'though', 'shoes', 'think'}
# Document 83: {'behaviour', 'imagine', 'question', 'discussing', 'frustrating', 'may'}
# Document 84: {'might', 'reply', 'say', 'think'}
# Document 85: {'worrying', 'creatively', 'might', 'thought', 'youve', 'think', 'ways'}
# Document 86: {'make', 'helps', 'reassurances', 'list', 'worries', 'reassuring'}
# Document 87: set()
# Document 88: {'talkers', 'thats', 'easy', 'find', 'family', 'discussing', 'many', 'way'}
# Document 89: {'still', 'families', 'calmly', 'find', 'arent', 'however', 'opportunity', 'mention'}
# Document 90: {'others', 'reassure', 'examples', 'plans', 'give', 'done'}
# Document 91: {'sympathies', 'disappointment', 'drop', 'fears', 'may'}
# Document 92: {'points', 'dont', 'miracle', 'conversation', 'expect', 'period', 'time'}
# Document 93: {'people', 'overnight', 'feel', 'dont', 'opinions', 'rarely', 'change'}
# Document 94: {'agreement', 'still', 'total', 'come', 'back', 'discussion', 'stop', 'good', 'going'}
# Document 95: {'days', 'later', 'serious', 'youre', 'see', 'worries'}
# Document 96: {'considered', 'bit', 'next', 'time', 'agreeable', 'probably'}
# Document 97: set()
# Document 98: {'simple', 'approach', 'obviously', 'similar', 'help', 'many', 'example'}
# Document 99: {'situations'}
# Document 100: set()
# Document 101: set()
# Document 102: {'dealing', 'personal', 'relationships', 'problems'}
# Document 103: set()
# Document 104: {'frequently', 'need', 'large', 'number', 'problems', 'sources', 'arise'}
# Document 105: {'influences', 'disentangle', 'help', 'care', 'problems', 'mixture'}
# Document 106: {'form', 'others', 'pressures', 'intensified', 'relationship', 'end'}
# Document 107: {'pressures', 'view', 'general', 'idealised', 'media', 'give', 'couples'}
# Document 108: {'people', 'odds', 'experience', 'many', 'often', 'reality'}
# Document 109: set()
# Document 110: {'simple', 'guidelines'}
# Document 111: set()
# Document 112: {'relationship', 'looking', 'know'}
# Document 113: {'entering', 'relationship', 'reasons', 'many', 'different'}
# Document 114: {'companionship', 'sexual', 'experience', 'create', 'partner', 'longterm'}
# Document 115: {'discussed', 'looking', 'know', 'family'}
# Document 116: {'partner'}
# Document 117: set()
# Document 118: set()
# Document 119: set()
# Document 120: set()
# Document 121: set()
# Document 122: set()
# Document 123: {'little', 'much', 'asking', 'expecting', 'relationship'}
# Document 124: {'companionship', 'sexual', 'provide', 'relationship', 'good', 'support', 'expression'}
# Document 125: {'build', 'looking', 'provide', 'joint', 'eventually', 'life', 'opportunity'}
# Document 126: {'sense', 'give', 'example', 'worth', 'protect', 'purpose'}
# Document 127: {'personal', 'deep', 'provide', 'fear', 'partner', 'trying', 'may', 'get'}
# Document 128: {'fact', 'brings', 'relationship', 'things', 'hand', 'achieve'}
# Document 129: {'grief', 'lower', 'far', 'continual', 'accepting', 'pain', 'stress', 'may'}
# Document 130: {'right', 'interaction', 'expect', 'particular', 'deserves', 'level', 'noone'}
# Document 131: {'sexual', 'emotionalpsychological', 'receiving', 'physical', 'violence', 'end'}
# Document 132: {'behaviour', 'need', 'abusecontrolling', 'support', 'end', 'change', 'look'}
# Document 133: {'happening', 'relationship', 'abuse'}
# Document 134: set()
# Document 135: {'build', 'model', 'relationship', 'trying', 'get'}
# Document 136: {'people', 'find', 'relationship', 'admire', 'many', 'picture', 'helpful'}
# Document 137: {'someone', 'aspire', 'know', 'fictional', 'relationship', 'wish', 'may'}
# Document 138: {'people', 'differences', 'consider', 'relationship', 'one', 'resolve', 'difficulties'}
# Document 139: {'particularly', 'finding', 'models', 'whether', 'task', 'important'}
# Document 140: {'heterosexual', 'samegender', 'bisexual', 'lesbian', 'gay', 'couples'}
# Document 141: set()
# Document 142: {'problems', 'talk'}
# Document 143: {'disagreement', 'relationships', 'times', 'serious', 'going'}
# Document 144: {'resolved', 'mean', 'doesnt', 'wrong', 'interests', 'conflict', 'something'}
# Document 145: {'agreement', 'arguing', 'point', 'relationship', 'however', 'reaching'}
# Document 146: {'practice', 'take', 'bit', 'skill'}
# Document 147: set()
# Document 148: {'talking', 'might', 'habit', 'relationship', 'interesting'}
# Document 149: {'well', 'relationships', 'try', 'exploring', 'give', 'worth', 'helpful'}
# Document 150: set()
# Document 151: {'rules', 'constructively', 'golden', 'arguing'}
# Document 152: set()
# Document 153: set()
# Document 154: set()
# Document 155: {'specific', 'start', 'know', 'arguing'}
# Document 156: set()
# Document 157: {'problem', 'time', 'resolving', 'devote'}
# Document 158: set()
# Document 159: {'make', 'sit', 'contact', 'eye'}
# Document 160: set()
# Document 161: {'speak', 'personally', 'feel'}
# Document 162: set()
# Document 163: {'makes', 'acknowledge', 'point', 'person', 'valid'}
# Document 164: set()
# Document 165: {'differ', 'agree'}
# Document 166: set()
# Document 167: {'stick', 'hand', 'matter'}
# Document 168: set()
# Document 169: {'arguing', 'violence', 'cease', 'separate', 'likelihood'}
# Document 170: set()
# Document 171: {'try'}
# Document 172: set()
# Document 173: {'aggressively', 'disrespectfully', 'behave'}
# Document 174: set()
# Document 175: {'hurt', 'deliberately', 'feelings', 'persons'}
# Document 176: set()
# Document 177: {'generalise'}
# Document 178: set()
# Document 179: {'unresolved', 'disputes', 'old', 'bring'}
# Document 180: set()
# Document 181: {'away', 'without', 'walk', 'discussion', 'resumed', 'deciding', 'unless'}
# Document 182: {'threatens', 'violence'}
# Document 183: set()
# Document 184: {'opinions', 'peoples', 'bring'}
# Document 185: set()
# Document 186: {'hour', 'something', 'argue'}
# Document 187: set()
# Document 188: {'night', 'drinking', 'late', 'argue'}
# Document 189: set()
# Document 190: {'relationships', 'great', 'relationship', 'range', 'difficulties'}
# Document 191: {'complex', 'clarify', 'counselling', 'allowing', 'help', 'resolve'}
# Document 192: {'relationship', 'problems'}
# Document 193: set()
# Document 194: set()
# Document 195: set()
# Document 196: set()
# Document 197: set()
# Document 198: set()
# Document 199: {'booksagencies'}
# Document 200: set()
# Document 201: {'relationships', 'relate', 'litvinoff', 'guide', 'vermilion', 'better', 'sarah'}
# Document 202: {'relationships', 'aspects', 'guide', 'easy', 'comprehensive', 'couple', 'read'}
# Document 203: {'includes', 'selfhelp', 'case', 'lot', 'histories', 'many', 'exercises'}
# Document 204: set()
# Document 205: {'sex', 'loving', 'relationships', 'relate', 'litvinoff', 'guide', 'vermilion', 'sarah'}
# Document 206: {'sexual', 'wealth', 'covers', 'resolve', 'difficulties'}
# Document 207: set()
# Document 208: {'talking', 'susan', 'point', 'start', 'stop', 'arguing', 'couples', 'conflict', 'plan'}
# Document 209: {'quilliam', 'vermilion'}
# Document 210: set()
# Document 211: {'relationships', 'boundaries', 'knowing', 'enjoying', 'protecting', 'self'}
# Document 212: {'whitfield', 'l', 'charles', 'hci'}
# Document 213: set()
# Document 214: {'relate', 'members', 'family', 'offers', 'relationship', 'help', 'problems', 'couples'}
# Document 215: {'tel'}
# Document 216: {'wwwrelateorguk', 'website'}
# Document 217: set()
# Document 218: {'robin', 'survive', 'families', 'cleese', 'vermilion', 'john', 'skynner'}
# Document 219: {'lighthearted', 'nonetheless', 'dynamics', 'family', 'many', 'book', 'explores'}
# Document 220: {'well', 'life'}
# Document 221: set()
# Document 222: set()
# Document 223: set()
# Document 224: set()
# Document 225: set()
# Document 226: set()
# Document 227: set()
# Document 228: set()
# Document 229: set()
# Document 230: set()
# Document 231: set()
# Document 232: set()
# Document 233: set()
# Document 234: set()
# Document 235: set()
# Document 236: set()
# Document 237: set()
# Document 238: set()
# Document 239: set()
# Document 240: set()
# Document 241: set()
# Document 242: set()
# Document 243: set()
# Document 244: set()
# Document 245: set()
# Document 246: set()
# Document 247: set()
# Document 248: set()
# Document 249: set()
# Document 250: set()
# Document 251: set()
# Document 252: set()
# Document 253: set()
# Document 254: set()
# Document 255: {'ntusssscsjuly'}
# Document 256: set()
# ####################################################################################################

# %% [markdown]
# MIna

# %%
Pdfs = ["Football_Basics.pdf", "Tennis SG.pdf", "NLPTrends.pdf", "Relationships.pdf"]

mdocs = []

for pdf_path in Pdfs:
    doc = fitz.open(pdf_path)

    page_text = ""
    for page in doc:
        page_text += page.get_text()

    mdocs.append(page_text)
    print(f"Content of {pdf_path}:")
    print(page_text)
    print(100*"#")
    print("\n")
# Out:
# Content of Football_Basics.pdf:
# Football Basics
# Check here if you're new to football, having a difficult time following the games or if you just need to look
# up some terms.
# The Basics of the Game
# One 11-man team has possession of the football. It is called the offense and it tries to advance the ball
# down the field-by running with the ball or throwing it - and score points by crossing the goal line and
# getting into an area called the end zone. The other team (also with 11 players) is called the defense. It
# tries to stop the offensive team and make it give up possession of the ball. If the team with the ball does
# score or is forced to give up possession, the offensive and defensive teams switch roles (the offensive
# team goes on defense and the defensive team goes on offense). And so on, back and forth, until all four
# quarters of the game have been played.
# The Playing Field
# The field measures 100 yards long and 53 yards wide. Little white markings on the field called yard markers
# help the players, officials, and the fans keep track of the ball. Probably the most important part of the
# field is the end zone. It's an additional 10 yards on each end of the field. This is where the points add up!
# When the offense - the team with possession of the ball-gets the ball into the opponent's end zone, they
# score points.
# The Players
# Each team has 3 separate units: the offense (see section below), those players who are on the field when
# the team has possession of the ball; the defense (see section below), players who line up to stop the other
# team's offense; and special teams that only come in on kicking situations (punts, field goals, and kickoffs).
# Only 11 players are on the field from one team at any one time.
# The Offense
# Whichever team has possession of the ball is the offense. While only the quarterback, the wide receivers
# and tight ends, and the running backs can legally handle the ball, it is the quarterback who is the leader of
# the team and the playmaker.
# The Offensive Players
# 
# The quarterback ("QB") passes or hands off the ball.
# 
# The center snaps the ball to the QB and blocks the defense.
# 
# 2 guards and 2 tackles keep the defense at bay.
# 
# 2/4 wide receivers catch the ball thrown by the QB.
# 
# 1 or 2 running backs take the ball and run with it.
# 
# 1 or 2 tight ends block the defense and can also catches passes.
#   The Defense
# The job of the defense is to stop the offense. The 11 men on the defensive team all work together to keep
# the offense from advancing toward the defense's end zone.
#
# The Defensive Players
# 
# Linebackers defend against the pass, and push forward to stop the run or tackle the QB.
# 
# The defensive line (ends and tackles) battles head-to-head against the offensive line.
# 
# Cornerbacks and safeties defend against the pass from the QB to the wide receiver and help to
# stop the run.
#
# Game Play
# Timing
# Games are divided into four 12-minute quarters, separated by a break at halftime.
# Officiating
# The NYFL typically will have “4” officials at the game, 1 referee, 1 umpire and 2 linesman. A game may start
# with three officials if agreed upon by both teams.
# The Kickoff
# A game starts with the kickoff. The ball is placed on a kicking tee at the defense's 40-yard line, and a
# special kicker (a "placekicker") kicks the ball to the offense A kick return man from the offense will try to
# catch the ball and advance it by running. Where he is stopped is the point from which the offense will begin
# its drive, or series of offensive plays. When a kickoff is caught in the offense's own end zone, the kick
# returner can either run the ball out of the end zone, or kneel in the end zone to signal a touchback - a sign
# to stop the play. The ball is then placed on the 20-yard line, where the offense begins play.
# First Down
# All progress in a football game is measured in yards. The offensive team tries to get as much "yardage" as
# it can to try and move closer to the opponent's end zone. Each time the offense gets the ball, it has four
# downs, or chances, in which to gain 10 yards. If the offensive team successfully moves the ball 10 or more
# yards, it earns a first down, and another set of four downs. If the offense fails to gain 10 yards, it loses
# possession of the ball. The defense tries to prevent the offense not only from scoring, but also from
# gaining the 10 yards needed for a first down. If the offense reaches fourth down, it can punt the ball (kick
# it away), this forces the other team to begin its drive further down the field.
# Moving the Ball
# The Run and the Pass play begins with the snap. At the line of scrimmage (the position on the field where
# the play begins), the quarterback loudly calls out a play in code and the player in front of him, the center,
# passes, or snaps the ball under his legs to the quarterback. From there, the quarterback can either throw
# the ball, hand it off, or run with it.
# 
# The Run: There are two main ways for the offense to advance the ball. The first is called a run.
# This occurs when the quarterback hands the ball off to a running back, who then tries to gain as
# many yards as possible by eluding defensive players. The quarterback is also allowed to run with the
# ball.
# 
# The Pass: The other alternative to running the ball is to throw it or pass it. Usually, the
# quarterback does the passing, though there are times when another player may pass the ball to
# confuse the defense. Actually, anyone on the offensive team is allowed to pass the ball as long as
# the pass is thrown from behind the line of scrimmage. A pass is complete if the ball is caught by
# another offensive player, usually the "wide receiver" or "tight end." If the ball hits the ground
# before someone catches it, it is called an incomplete pass.
# The Tackle
# The defense prevents the offense from advancing the ball by bringing the ball carrier to the ground. A
# player is tackled when one or both of his knees touch the ground. The play is then over. A play also ends
# when a player runs out of bounds.
# Turnovers
# While trying to advance the football to the end zone, the offense may accidentally turn the ball over to the
# defense in one of two ways:
# 
# The Fumble: When the ball carrier or passer drops the ball, that's a fumble. Any player on the field
# can recover the ball by diving on it or he can run with it. The team that recovers a fumble either
# gets-or retains-possession of the ball.
# 
# The Interception: An aggressive defense can regain possession of the ball by catching
# (intercepting) passes meant for players on the other team. Both fumble recoveries and
# interceptions can be run back into the end zone for touchdowns. Also referred to as a pick.
#
# Helpful Terms and Definitions
# Audible: When the quarterback changes the football play at the line of scrimmage.
#
# Backfield: This is the area of the football field behind the line of scrimmage.
#
# Backs: These football players include the running backs, the halfback and the fullback.
#
# Blitz: A football play where the defensive team rushes more football players than usual to try and sack the
# quarterback.
#
# Blocking: What the offensive team does to prevent a defensive player from getting to the football carrier;
# Blockers use their arms and bodies to get in the way, but may not grab onto (hold) an opponent.
#
# Bump-and-run: When pass defenders hit a receiver once and then follow him to prevent him from catching
# a pass.
#
# Eligible receiver: Only certain football players on the offense are allowed by the rules to catch a forward
# pass; All the linemen and the quarterback are not eligible unless they notify the referee before the snap.
# The linemen must stand at least one yard behind the line of scrimmage.
#
# Encroachment: A penalty when any football player other than the center is in the neutral zone and contact
# occurs prior to the snap.
# End zone: This is the area where the football team must enter with the football to score a touchdown.
#
# Extra point: After a football team has scored a touchdown, they have the opportunity to score extra
# points via the point-after-touchdown (1 point) or a 2-point conversion (2 points).
#
# Fair catch: The player making a football kick return can decide to catch a punt or kickoff and not advance
# the football. He must signals for a fair catch by raising one hand in the air and waving it.
#
# Field goal: The kicker must kick the football above the crossbar and between the uprights of the goalpost.
# The football team that kicked the football gets 3 points.
#
# Forward pass: When the football is thrown by a football player (typically the quarterback) towards the
# opponent’s goal line. On a play from scrimmage, only one forward pass can be thrown by the football team
# and it must be thrown from behind the line of scrimmage.
#
# Forward progress: The spot where a football carrier has moved the football regardless of whether he was
# pushed backwards from that spot.
#
# Fumble: When a football player drops the football. Whoever picks it up will gain possession for his team.
#
# Goalpost: The structure in the end zone that the kicker must kick the football through to score an extra
# point or a field goal.
#
# Holding: A penalty where a football player stops the movement of an opponent by grasping or holding onto
# his body or uniform.
#
# Intentional grounding: A penalty when the quarterback purposely throws an incomplete pass just to avoid a
# sack.
#
# Interception: A pass that is caught by a football player on the defense.
#
# Kickoff: When a football player kicks the football to the other team. This happens at the start of the
# game, the second half and overtime, and after each score.
#
# Lateral: A pass thrown that is backwards from the team’s line of scrimmage. Football players may lateral
# the football as many times per play as they want.
#
# Line of scrimmage: The place on the field where the football is spotted and the next play starts.
#
# Lineman: The offensive and defensive football players who start each play at the line of scrimmage.
#
# Neutral zone: The area between the offense and defense where the football as it sits on the ground
# before each play.
#
# Nickel defense: When the defense brings in a 5th defensive back to help cover the pass play.
#
# Offside: A penalty that occurs when any part of a football player’s body is beyond his line of scrimmage
# when the football is snapped.
#
# Pass protection: Blocking by the offensive football players to keep defenders away from the quarterback
# to give him time to throw the football.
# Pass rush: When a defender tries to get by the blockers to sack the quarterback.
#
# Personal foul: A penalty for any action that had intent to cause injury to another football player.
#
# Place kick: When the kicker tries to kick the football between the goal post. The football is held by
# another player between his finger and the ground.
#
# Play-action pass: When the quarterback fakes handing off the football, then tries to make a pass.
#
# Pocket: The area where the quarterback stands and is protected from the rush by his blockers.
#
# Punt: When a football team kicks the football to the other team rather than loose the football on downs.
# The kicker holds the football in his hands and kicks it to the other football team.
#
# Quarterback: This is the football player that starts each play. He takes the snap from the center and
# either runs with it, hands off the football to another player, or passes it.
#
# Receivers: The football players who catch the football.
#
# Rush: When the football player runs with the football.
#
# Sack: When the quarterback is tackled behind the line of scrimmage.
#
# Safety: When a football player is tackled in his own end zone. The defense gets 2 points and the football
# off of a free kick.
#
# Scrambling: When the quarterback runs around trying not to get sacked with the football.
#
# Snap: Sometimes called the hike. The center hands off the football between his legs to a player standing
# behind him (usually the quarterback) at the start of each play.
#
# Special teams: These are the football players who are involved in the kicking plays.
#
# Spot: Where the official decides the line of scrimmage will be for the start of the next football play.
#
# Tackle:
# 1.
# A football player position on the offensive or defensive line. There are two of them and they play
# on each side of the center or the nose guard.
# 2. When a football player causes the football carrier to touch the ground such that they are
# considered down.
#
# Touchdown: The main object of football. When a player has control of the football within the end zone his
# team gets 6 points.
#
# Turnover: When, with either a fumble or an interception, one team loses possession of the football to the
# other.
#
#
# ####################################################################################################
#
#
# Content of Tennis SG.pdf:
# TENNIS  RULES
# STUDY GUIDE
#
# I.
# THE TENNIS COURT:
#
#
#
#
#
#
# Doubles Alley
#
#
#
# Doubles Side Line
#
#        Singles Side Line
# Back Court
#
#
#
#
#
#
#
#
#        Right Service Court
# Base Line
#
#
#
#     Back Service Line
# Center Mark
#                                 Net (3’)
# Left Service Court
# Center Service
#
# Fore Court
# Line
#
# II.
# TENNIS RULES:
# A. Single’s Game:  (Two people total)
# 1. The player winning the coin toss or spin of the racket may choose to:
# a. To be server or receiver
# b. Choose the side of the net. (Hint: If it is sunny out, may want to be on
# the side not facing the sun)
# B. Double’s Game:  (Four people; two on each side)
# 1. The same rules apply for doubles as for singles, with these exceptions:
#    a.   The outside boundary lines enclosing the alleys are used.  (This does
#
# apply to the service, which must still fall inside the service court.)
# b. Order of service: A and B are partners against C and D.  First game:
# A serves, Second game: C serves, Third game: B serves, Fourth game:
# D serves, etc.  This order is maintained throughout the SET.
# ( A SET is the winning of six games or by winning two consecutive
# games after each team has won five games.)
#
# III.
# SERVICE:
# A. Delivery:
# 1. Both feet of the server must be behind the baseline and inside of the center mark
# and the singles sidelines.  ( If they are not it is called a FOOT FAULT) The server
# loses the point.
# 2. Must toss the ball into the air and strike it before it touches the ground.
# 3. Must serve across the net into the diagonal court.
# 4. Shall start in the right court in every game.
# 5. After the first point they alternate courts.
# 6. Any ball striking a line is FAIR or IN.
# 7. Server has two (2) chances on each serve to get it in the correct court.  (The first
# error or goof causes a FAULT.
# 8. May not serve until the receiver is ready.  (Calling out the SCORE is a good way to
# say you are ready to serve and the server should always call their score first.)
# B. Faults:
# 1. Foot fault by steeping over the line.
# 2. The ball is sent anywhere outside the boundaries of the diagonally opposite service
# court or into the net.
# 3. The server misses the ball in attempting to strike it.
# 4. Two (2) faults in succession is called a DOUBLE FAULT and the server loses the
# point.
# C. Let:  REPLAYS THE POINT
# 1. The ball tips the net and falls into the correct service court.
# 2. The ball is served when the receiver is not ready.
# 3. There is any outside interference during the serve or during the play following it.
# 4. Any play where there is a question of being legal.
# 5. When a LET is called during any circumstance- the ball is replayed.
# IV.
# SCORING:
# A. Game:
#
#    Love ……………….zero (nothing)
#                1st point…………….15 (fifteen)
#
#    2nd point……………30 (thirty)
#
#    3rd point……………40 (forty)
#
#    4th point……………Game…..provided one player or team is two (2) points ahead.
# B.  Deuce:   Tie = equal score
#
#    1.  A score of 40-40 and any tie score thereafter is called DEUCE.
#
#    2.  AD-IN:  (Advantage Server) is the first point after deuce IF the server wins the point.
#
#    3.  AD-OUT:  (Advantage Receiver) is the first point after deuce IF the receiver wins the
# point.
# 5.  EXPLANATION:  A game may go back to deuce any number of times, but must
# continue until one player is ahead by two.
# EXAMPLE:
# a. Player A (server) has two points, Player B (receiver) has three points.
# SCORE =  30-40
# b. A earns the next point.  SCORE = 40-40 or DEUCE
# c. B earns the next point.  SCORE = Advantage Receiver or AD-OUT
# d. A earns the next point.  SCORE = DEUCE
# e. B earns the next TWO points.  SCORE= Game, receiver.
#
# V.
# CHANGING SIDES OF THE COURT:
# A. Players change sides of the net after every ODD NUMBER of games
# (Such as 1, 3, 5, 7, ect.)
# VI.
# A SET:   First team to win 6 games.
#
# VI.
# A MATCH:  Next scoring unit after SET.  Best 2 out of 3 sets.
#
#
#
#
#
# TENNIS  TERMINOLOGY
#
# 1. Backhand:  Stroke used to hit balls on the left side of a right handed player and on
# the right side of a left handed player.
# 2. Forehand:  Stroke used to hit balls on the right side of a right handed player and on
# the left side of a left handed player.
# 3. Lob:  A high arching shot that lands near the baseline.
# 4. Serve:  The stroke used to put the ball into play at the beginning of each point.
# 5. Volley:  The stroke used to hit the ball in the air before it has bounced.
# 6. Rally:  Hit ball back and forth for long periods of time.
#
# EQUIPMENT:       COURT, RACKET, AND AT LEAST TWO BALLS
#
# ETIQUETTE THOUGHT: Begin each point with two balls in server’s possession.  Saves time and
# helps keep track of the faults on the serve.
#
#
# 1. HEAD:  The part of the racket above the throat
#                     that includes the frame and the strings.
# 2.  FACE:   The hitting surface of the racket.
#
#
#
#
#
#
#
#
#       Open face- racket turned so that hitting
#
#
#
#
#
#
#
#
#        surface is facing upward.
#
#
#
#
#
#
#
#
#        Closed face – racket turned so that the
#
#
#
#
#
#
#
#
#         hitting surface is facing downward.
#
#
#
#
#
#
#
#
#         Flat face – hitting surface of racket facing
#
#
#
#
#
#
#
#
#          the net and perpendicular to the ground.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3.  THROAT:  The wooden or aluminum part of
#
#
#
#
#
#
#
#
#       the frame, just below the racket head.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4.  HANDLE:  (Grip)  The wooden shaft of the racket (or
#
#
#
#
#
#
#      aluminum) which is covered with leather and gripped by
#
#
#
#
#
#
#      the hand.
#
# 5. TRIM:  Small stringing at the top and bottom of the racket
# Head for the purpose of holding the main strings in place.
#
#
# ####################################################################################################
#
#
# Content of NLPTrends.pdf:
# LREC-COLING 2024, pages 5696–5710
# 20-25 May, 2024. © 2024 ELRA Language Resource Association: CC BY-NC 4.0
# 5696
# Emotion Analysis in NLP:
# Trends, Gaps and Roadmap for Future Directions
# Flor Miriam Plaza-del-Arco1, Alba Curry2,
# Amanda Cercas Curry1, Dirk Hovy1
# 1MilaNLP, Bocconi University, Department of Computing Sciences, Milan, Italy
# 2School of Philosophy, Religion and History of Science, University of Leeds
# {flor.plaza, amanda.cercas, dirk.hovy}@unibocconi.it
# a.a.cercascurry@leeds.ac.uk
# Abstract
# Emotions are a central aspect of communication. Consequently, emotion analysis (EA) is a rapidly growing field
# in natural language processing (NLP). However, there is no consensus on scope, direction, or methods. In this
# paper, we conduct a thorough review of 154 relevant NLP publications from the last decade. Based on this review,
# we address four different questions: (1) How are EA tasks defined in NLP? (2) What are the most prominent
# emotion frameworks and which emotions are modeled? (3) Is the subjectivity of emotions considered in terms of
# demographics and cultural factors? and (4) What are the primary NLP applications for EA? We take stock of trends
# in EA and tasks, emotion frameworks used, existing datasets, methods, and applications. We then discuss four
# lacunae: (1) the absence of demographic and cultural aspects does not account for the variation in how emotions are
# perceived, but instead assumes they are universally experienced in the same manner; (2) the poor fit of emotion
# categories from the two main emotion theories to the task; (3) the lack of standardized EA terminology hinders gap
# identification, comparison, and future goals; and (4) the absence of interdisciplinary research isolates EA from
# insights in other fields. Our work will enable more focused research into EA and a more holistic approach to modeling
# emotions in NLP.
# Keywords: emotion analysis, survey, trends, gaps.
# 1.
# Introduction
# Emotions perfume our every experience and in-
# teraction, playing a key role in human cognition
# and relationships. In recent decades, research on
# emotion has become popular in numerous fields,
# including psychology, humanities, and social sci-
# ences. In natural language processing (NLP), inter-
# est in emotion mostly translates as emotion anal-
# ysis (EA), whose growth has been most notable
# since 2018 (Strapparava and Mihalcea, 2008; Mo-
# hammad et al., 2018; Klinger et al., 2018; Plaza-del-
# Arco et al., 2018; Nissim et al., 2020; Mohammad,
# 2021; Plaza-del-Arco et al., 2022b; Barnes et al.,
# 2022).
# We survey1 over 150 ACL papers (2014-2022)2
# on EA to address four questions: (1) How are EA
# tasks defined in NLP? (2) What are the most promi-
# nent emotion frameworks, and which emotions are
# modeled? (3) Is the subjectivity of emotions consid-
# ered in terms of demographics and cultural factors?
# (4) What are the primary NLP applications for EA?
# We find a lack of consensus in terms of the scope,
# direction, and methods in the current studies, which
# raises three important concerns:
# 1Note that our main goal is not a complete snapshot
# of the EA field but rather a snapshot of specific method-
# ological issues within EA in NLP.
# 2For our selection criteria, see Section 3.
# The scene in the movie where
# the two lovers walk hand in
# hand at sunset…
# Emotion evoked
# Nostalgia
# Excitement
# Age: 60
# Age: 20
# Figure 1: Variation in emotion annotation based
# on demographics. Annotators with distinct demo-
# graphic profiles, a 60-year-old male and a 20-year-
# old male, exhibit varying interpretations of the emo-
# tions evoked.
# 1. The absence of demographic and cultural as-
# pects does not account for the variation in how
# emotions are presented and perceived but as-
# sumes they are universally experienced in the
# same manner. There is a general lack of en-
# gagement with recent work on how emotions
# are racialized (Judd, 2019), gendered (Camp-
# bell, 1994), etc. In other words, who produces
# the data matters (see Figure 1) and who anno-
# tates it.
# 2. The poor fit of emotion categories to the task
# poses a significant challenge. The commonly
# used predefined emotion categories may not ad-
# 5697
# equately capture the nuances required for the
# downstream task.
# 3. The lack of a common systematic nomenclature
# in EA obscures gaps, limits comparison, and,
# therefore, future objectives. For example, our
# survey shows that ‘prediction’ is synonymous
# with ‘classification.’ In other areas of NLP, these
# two terms are used for distinct tasks.
# 4. The dearth of interdisciplinary research means
# progress in other fields does not inform EA. A
# main problematic area is at the level of task de-
# sign: NLP still predominantly relies on the work
# of Paul Ekman (Ekman and Friesen, 1981). Ek-
# man’s work addressed the question of basic emo-
# tions, not to provide a comprehensive account
# of emotions nor to define the most ‘helpful’ emo-
# tions. Thus, the categories this theory provides
# are too broad and oversimplified to be useful
# across tasks and languages (De Bruyne, 2023).
# Emotions are crucial in real-life applications. This
# paper also explores the diverse range of emotion
# applications, focusing on dialogue emotion recog-
# nition as the most prominent and widely used. We
# analyze widely used datasets tailored for this pur-
# pose, highlighting their key characteristics.
# Unlike previous surveys in the field, ours focuses
# on unexplored questions, revealing critical gaps in
# the EA field that require community attention. We
# aim to connect these gaps, fostering focused re-
# search and nuanced emotion modeling in NLP. We
# conclude with recommendations and suggestions
# for future work.
# 2.
# Related Work
# EA has attracted considerable research interest.
# Various surveys provide a comprehensive overview
# of the state of the field (Canales and Martínez-
# Barco, 2014; Yadollahi et al., 2017; Garcia-Garcia
# et al., 2017; Mäntylä et al., 2018; Kim and Klinger,
# 2018a; Saxena et al., 2020; Acheampong et al.,
# 2020). Recent surveys (Murthy and Kumar, 2021;
# Kusal et al., 2022b; Singh Tomar et al., 2023) have
# primarily focused on the identification of datasets,
# models, detection techniques, affective computing
# modalities (visual, vocal, textual, etc.), and appli-
# cations in the literature. While these surveys ac-
# knowledge certain limitations in EA, such as the
# scarcity of labeled datasets, data imbalance, the
# dominance of English, and the performance of NLP
# methods, most of them do not address the signifi-
# cant gaps we discuss. Specifically, most disregard
# the significance of demographic factors in their anal-
# ysis (with a brief mention of the work by Sailunaz
# et al. (2018)), aggregation methods for collecting
# annotator perspectives, or the importance of inter-
# disciplinarity.
# Mohammad (2022) conducted a comprehensive
# analysis of AI Ethics and Emotion Recognition liter-
# ature, synthesising 50 ethical considerations rele-
# vant to automatic emotion recognition. His work pro-
# vides valuable ethics pointers that consider some
# topics we covered here, such as the crucial consid-
# eration of demographic factors and the modeling
# of annotators’ perspectives during dataset creation.
# The gaps we identified demonstrate the inherent
# connection between ethics and advancements in
# NLP for EA.
# 3.
# Survey of Emotion Analysis in NLP
# In this section, we present our survey of papers
# from the ACL Anthology3. To ensure a compre-
# hensive selection of studies on EA, we focused on
# identifying papers whose titles or abstracts include
# keywords associated with EA NLP tasks in the field.
# They are ‘emotion analysis’, ‘emotion prediction’,
# ‘emotion classification’, ‘emotion detection’, ‘emo-
# tion recognition’, ‘emotion polarity classification’,
# and ‘emotion cause detection.’4 As EA increased in
# frequency after 2018, we doubled the time horizon
# to consider papers published in the last ten years.
# We removed duplicates and papers from shared
# task participants, resulting in 438 studies. We ap-
# plied additional criteria to ensure the inclusion of
# influential and relevant works in our survey. Specifi-
# cally, we opted for papers with a citation count from
# Semantic Scholar surpassing the median average
# (excluding self-citations). However, we adjusted
# this threshold to at least 1 citation for papers pub-
# lished in the last and current year. Following this
# selection process, our final analysis set contains
# 154 papers5. Among these, 119 are published in
# main conferences, 31 in workshops, 3 in Findings,
# and 1 in other venues. For each paper, we col-
# lected the following information: Emotions used,
# emotion model type, emotion model, language, re-
# source (dataset, lexicon), data source, presence
# of multimodality (yes, no), nomenclature used, and
# applications. If a paper focuses on dataset cre-
# ation, we also determined whether the annotators’
# demographics were considered.
# Figure 2 provides an overview of the 154 papers
# by year and keyword. There is a clear trend in the
# number of papers from 2014 to 2022, with 2018
# marking a significant increase in the appearance of
# 3At the time of this study (September 2023), the ACL
# Anthology contained 88,294 papers, including those from
# non-ACL events like LREC.
# 4While we acknowledge the existence of other rel-
# evant terms in EA, most papers pertinent to our core
# questions use predominantly these terms.
# 5We
# provide
# the
# survey
# data
# on
# GitHub:
# https://github.com/MilaNLProc/emotion_
# analysis_survey.
# 5698
# Figure 2: Distribution of papers considered in our
# survey by year and keyword.
# EA studies. This jump indicates a growing interest
# in the field during the last five years.
# 3.1.
# Nomenclature
# Figure 2 also provides an overview of the com-
# monly used terms to describe EA tasks. The term
# ‘emotion recognition’ stands out as the most fre-
# quently used (42.48%), followed by ‘emotion analy-
# sis’ (28.10%), emotion classification (13.07%), and
# ‘emotion detection’ (12.41%). ‘Emotion prediction’
# and ‘emotion cause detection’ are the least used
# terms.
# However, during our analysis, we note that
# these terms are not used in isolation. Figure 3
# highlights the most prevalent pairs of terms used
# across different papers to refer to these tasks.
# The most frequent pair, ‘classification-recognition,’
# is used interchangeably across the papers, fol-
# lowed by ‘classification-analysis’ and ‘classification-
# detection.’ This variation indicates a lack of stan-
# dardized terminology for EA tasks.
# Given the lack of uniformity, providing definitions
# for each term is challenging. We have chosen EA
# as the broad category that demarcates any emotion-
# related tasks in NLP. It should be distinguished
# from sentiment analysis or opinion mining. There is
# consensus in the literature that sentiment analysis
# refers to identifying whether someone expresses a
# positive or negative attitude (Yadollahi et al., 2017).
# Sentiments are differentiated from emotions by the
# duration in which they are experienced (Munezero
# et al., 2014). In contrast, EA is primarily interested
# in specific emotions such as anger or joy. In the
# literature reviewed, the task of emotion recogni-
# tion/detection/classification/prediction refers to the
# goal of identifying a specific emotion expressed by
# the author of a particular utterance or set of utter-
# ances (Mohammad et al., 2018; Chatterjee et al.,
# 2019). In some cases, it refers to the task of identi-
# fying the cause of emotions in a broader context,
# for example, how speakers affect each other’s emo-
# tional state in a conversation (Liu et al., 2022; Zhan
# et al., 2022). We discuss in Section 4.2 the issues
# that arise from the lack of consistent terminology.
# 3.2.
# Emotion Models and Frameworks
# Several conceptual models from psychologists and
# neuroscientists have emerged to categorize and in-
# terpret emotions. Notably, three prominent models
# stand out: the discrete or categorical model, the
# dimensional model, and the componential model.
# They are described in the following:
# • Discrete or categorial model: Emotions are
# categorized into distinct classes and cate-
# gories in this model. Each emotion is treated
# as independent and separate from others.
# This model includes well-known frameworks
# such as Ekman’s model (Ekman and Friesen,
# 1981) consisting of six basic emotions (anger,
# fear, sadness, joy, disgust and sur-
# prise) and Plutchik’s model (Plutchik, 1982),
# which encompasses eight primary emotions
# (anger, anticipation, disgust, fear,
# joy, sadness, surprise, and trust).
# • Dimensional model:
# Unlike the previous
# model, dimensional models view emotions as
# interconnected rather than independent enti-
# ties. This model acknowledges that emotions
# can vary in intensity and can be represented
# along different dimensions. For instance, emo-
# tion names are located in vector spaces of
# affect that consider valence, arousal, and dom-
# inance (VAD) (Russell and Mehrabian, 1977).
# • Componential
# model:
# The
# componen-
# tial model comprised the appraisal theory
# (Scherer, 1999; Lazarus, 1991), which em-
# phasizes that emotions are influenced by a
# person’s subjective evaluation or appraisal of
# a situation or experience. Factors such as
# responsibility, certainty, pleasant-
# ness, control, and attention play a sig-
# nificant role in influencing an individual’s emo-
# tional responses to a particular situation or
# experience (Smith and Ellsworth, 1985).
# Our analysis reveals a clear prevalence of dis-
# crete conceptual models in the literature, indicating
# a strong interest in classifying emotions into distinct
# categories and treating each emotion as an inde-
# pendent entity – in line with standard supervised
# learning objectives. However, a few papers use di-
# mensional models, and an even smaller proportion
# explore componential models.
# 5699
# Figure 3: Most common nomenclature pairs for EA tasks used in the literature.
# Figure 4: Most common emotion categories used
# in the EA literature.
# Research papers in discrete or categorical emo-
# tion models commonly rely upon different theories.
# The most influential theory is the Ekman model (Ek-
# man and Friesen, 1981), followed by the Plutchik
# model (Plutchik, 1982). A few other studies consid-
# ered the Turne list (Turner, 2000) and the Ortony,
# Clore, and Collins model (Ortony et al., 1988). With
# dimensional models, some studies used a mapping
# approach to associate emotion categories with di-
# mensions. For instance, Bagher Zadeh et al. (2018)
# conducted data annotating mapping the Ekman
# emotions to a Likert scale in which values are as-
# signed from 0 to 3 to represent the presence of emo-
# tions. Park et al. (2021) introduced a framework
# that leverages VAD scores obtained from an emo-
# tion lexicon to acquire VAD scores from sentences
# labeled with categorical emotions. More recently,
# componential models have gained attention and
# been introduced in the field. Hofmann et al. (2020)
# established an annotation task where event de-
# scriptions are linked to seven appraisal dimensions
# (Smith and Ellsworth, 1985). Stranisci et al. (2022)
# relied on Roseman’s model of appraisal (Roseman,
# 1991) to annotate a corpus of social media posts.
# More recently, (Troiano et al., 2023) built a corpus
# where people described emotion-triggering events
# and their appraisals. Subsequently, readers were
# asked to reconstruct emotions and appraisals from
# the text. They provide a thorough appraisal theory
# overview for text-based emotion analysis suitability
# assessment. Additionally, it shows that appraisals
# offer an alternative computational approach to EA
# and enhance emotion categorization in text using
# joint models.
# Figure 4 provides an overview of the most fre-
# quent emotion categories in the literature. Due to
# the widespread use of Ekman’s model (Ekman and
# Friesen, 1981), the prevalent emotions observed
# are anger, fear, sadness, joy, disgust, and
# surprise. Additionally, Plutchik’s model, which is
# the second most used, highlights the frequency of
# trust and anticipation. However, a range of
# other emotions receives comparatively less atten-
# tion. These include excitement, anxiety, op-
# timism, pessimism, guilt, shame, and love.
# 3.3.
# Data
# In this section, we provide an overview of the
# datasets that have been extensively used in various
# EA studies and more recently developed datasets.
# In our analysis, we identified over 50 papers that
# created a dataset. Table 1 gives a summary list
# of some of these datasets, showcasing their key
# characteristics: annotation scheme, language, mul-
# timodality, source, and size.
# Most of the datasets found in the EA studies
# are focused on emotion recognition in conversa-
# 5700
# Dataset
# Annotation
# Lang.
# Source
# Size
# IdeDialog (Ide and Kawahara,
# 2022)
# P
# JA
# Twitter dialogues
# 13,806
# M3ED (Zhao et al., 2022)
# E + neutral
# CN
# TV dialogues
# 24,449
# MuSE (Jaiswal et al., 2020)
# sad,
# anger,
# contentment,
# amusement, neutral
# EN
# Recordings
# 28 speak-
# ers
# MELD (Zahiri and Choi, 2017; Po-
# ria et al., 2019)
# E + neutral
# EN
# Movie dialogues
# 13,000
# DailyDialog (Li et al., 2017)
# E + other
# EN
# Movie dialogues
# 13,118
# EmoryNLP
# (Zahiri
# and
# Choi,
# 2017)
# E + neutral
# EN
# TV show dialogues
# 12,606
# IEMOCAP (Busso et al., 2008)
# happiness, anger, sadness,
# frustration, neutral
# EN
# Dyadic interactions
# 10,039
# StudEmo (Ngo et al., 2022)
# 28 emotion categories
# EN
# Customer reviews
# 5,182
# RED v2 (Ciobotaru et al., 2022)
# P - disgust, anticipation
# RO
# Tweets
# 5,449
# APPReddit (Stranisci et al., 2022)
# appraisals (Roseman, 1991)
# EN
# Reddit
# 1,091
# Universal Joy (Lamprinidis et al.,
# 2021)
# anger, anticipation, fear, joy,
# sadness
# 18
# Facebook posts
# 530k
# WRIME (Kajiwara et al., 2021)
# P, emotion intensity
# JA
# SNS posts
# 17,000
# EmoEvent (Plaza-del-Arco et al.,
# 2020)
# E + neutral
# EN-ES
# Tweets
# 8,409
# GoodNewsEveryone
# (Bostan
# et al., 2020)
# 15 emotion categories
# EN
# News Headlines
# 5,000
# PO-EMO (Haider et al., 2020)
# joy, sadness, uneasiness, vi-
# tality, suspense, sublime, hu-
# mor, annoyance, nostalgia
# EN-DE
# Poems
# 64
# (EN),
# 18 (DE)
# enISEAR (Hofmann et al., 2020)
# appraisals
# (Smith
# and
# Ellsworth, 1985)
# EN
# Self-reports
# 1,001
# Table 1: EA datasets. [E] Ekman, [P] Plutchik. The first part of the table contains multimodal datasets
# used for emotion recognition in conversation. The second part contains datasets used in EA and recent
# ones. Lang.: Language
# tion, including IdeDialog (Ide and Kawahara, 2022),
# M3ED (Zhao et al., 2022), MuSE (Jaiswal et al.,
# 2020), MELD (Zahiri and Choi, 2017; Poria et al.,
# 2019), DailyDialog (Li et al., 2017), EmoryNLP (Za-
# hiri and Choi, 2017), and IEMOCAP (Busso et al.,
# 2008). The annotation scheme used in most of
# these datasets follows the discrete or categorical
# model, specifically the Ekman model theory. How-
# ever, IdeDialog uses the Plutchik model, which en-
# compasses different emotion categories. Addition-
# ally, IEMOCAP and MuSE use their own unique
# annotation scheme. In terms of language, most of
# these datasets feature primarily English dialogues,
# except for M3ED, which incorporates Chinese di-
# alogues, and IdeDialog, which includes Japanese
# dialogues. These datasets are multimodal, includ-
# ing text, audio, and visual information. Moreover,
# the dialogues in these datasets are sourced from
# diverse domains, including movies, dyadic interac-
# tions, TV shows, Twitter, and recordings.
# In the second part of the table, we summarize
# some of the recent EA datasets created over the
# past few years. These datasets include StudEmo
# (Ngo et al., 2022), RED v2 (Ciobotaru et al., 2022),
# APPReddit (Stranisci et al., 2022), Universal Joy
# (Lamprinidis et al., 2021), WRIME (Kajiwara et al.,
# 2021), EmoEvent (Plaza-del-Arco et al., 2020),
# GoodNewsEveryone (Bostan et al., 2020), PO-
# EMO (Haider et al., 2020), and enISEAR (Hofmann
# et al., 2020). The annotation schemes of these
# datasets offer a wider range of emotion frame-
# works and emotions compared to the previously
# described for emotion recognition in conversation.
# While most adhere to the discrete emotion model,
# enISEAR and APPReddit incorporate the compo-
# nential model with appraisals. Although English
# is the most predominant language, multilingual
# datasets like EmoEvent and Universal Joy encom-
# pass multiple languages. RED includes Romanian,
# and WRIME includes Japanese, further diversify-
# 5701
# ing the linguistic coverage of emotion recognition
# studies. None of these datasets present a mul-
# timodal aspect. The instances are sourced from
# diverse domains, including social media (Twitter,
# Facebook), news headlines, self-reports, poems,
# customer reviews, and community networks (Red-
# dit). Among these domains, social media emerges
# as the most predominant data source.
# Despite the highly subjective nature of emotions,
# only a few works (Martin et al., 2022a; Zhan et al.,
# 2022; Ghosh et al., 2022) mentioned the gathering
# of annotator demographic information, yet most of
# them do not use this information for their methods.
# 3.4.
# Applications
# Studying patterns of human emotions and under-
# standing people’s feelings are essential in many
# real-life applications (Picard, 2000). In our analy-
# sis, among the most used applications, we found
# that emotion recognition in conversation has gained
# significant popularity in the field by analyzing the
# emotions expressed during interactions (Hazarika
# et al., 2018; Zhong et al., 2019; Ghosal et al., 2020;
# Hu et al., 2021; Lee and Lee, 2022). Another note-
# worthy application within the realm of EA is its ap-
# plication in the analysis of narrative texts (Kim and
# Klinger, 2018b; Liu et al., 2019; Haider et al., 2020;
# Zad and Finlayson, 2020; Cortal et al., 2023). Ad-
# ditionally, EA has found a valuable niche in the
# healthcare sector, particularly in addressing mental
# health concerns (Khanpour and Caragea, 2018).
# With the advent of social media, detecting and mon-
# itoring emotional states associated with mental well-
# being has become possible. This capability has
# proven invaluable in identifying individuals at risk
# of self-harm, anxiety, or stress, as detailed by Tur-
# can et al. (2021). EA also proves beneficial during
# critical events like the COVID-19 pandemic (Ng
# et al., 2020; Sosea et al., 2022; Sampath et al.,
# 2022). Beyond these applications, EA extends its
# impact to various other domains including email
# customer care (Gupta et al., 2010), span prediction
# (Alhuzali and Ananiadou, 2021), fake news (Mel-
# leng et al., 2019), moral content detection (Asprino
# et al., 2022), sarcasm detection (Chauhan et al.,
# 2020a,b), time series analysis of emotional loading
# in central bank statements (Buechel et al., 2019),
# and financial forecasting (Seroyizhko et al., 2022).
# 4.
# Shortcomings of EA in NLP
# In this section, we outline the main areas where
# there is room for improvement in EA research.
# 4.1.
# Lack of Diversity in Available
# Datasets
# We find significant overlap between datasets: most
# are in English, sourced from movies or TV shows,
# and annotated using Ekman’s emotions categori-
# cally. The lack of language diversity in NLP has
# been discussed at length (Martin et al., 2022b;
# Sonu et al., 2022), and it is not specific to EA, but
# EA lacks diversity in other aspects:
# Diversity in emotion labels
# Section 3.3 shows
# that most datasets are labeled according to Ek-
# man’s basic emotions, or Plutchik to a lesser extent.
# While these emotions are widely used in the ana-
# lyzed studies, they do not generalize to all tasks
# or domains (De Bruyne, 2023). Human emotions
# are nuanced because this nuance is required for
# understanding the world. Yet current datasets pre-
# dominantly focus on a few coarse-grained emotions.
# For example, feeling guilty or lonely both fall un-
# der sadness but convey very different meanings.
# Furthermore, the most commonly annotated emo-
# tions are negative, particularly anger, fear, and
# sadness. This emphasis on negative emotions
# has far-reaching consequences for EA and down-
# stream applications. Detecting more fine-grained
# negative emotions might be helpful in a mental dis-
# order detection setting, but positive emotions may
# be more relevant for tutoring systems as they aid
# learning. A notable example demonstrating the im-
# portance of aligning emotion categories with the
# specific task at hand is the work of (Haider et al.,
# 2020), where aesthetic emotions play a pivotal role
# in analyzing emotions within poems. This approach
# encompasses emotions such as joy, sadness,
# uneasiness, vitality, suspense, sublime,
# humor, annoyance, and nostalgia.. It is also
# noteworthy that most of the papers in the survey
# did not specify any concrete application of EA –
# lacking guidance in selecting the labels that will aid
# in a given task.
# Diversity in annotation schemes
# The prefer-
# ence for Ekman’s or Plutchik’s models significantly
# limits the adaptability of EA techniques to different
# contexts and tasks (Plaza-del-Arco et al., 2022a).
# Each NLP task may require a nuanced understand-
# ing of emotions that these models might not fully
# capture. This limitation impedes the development
# of more versatile and context-specific emotion anal-
# ysis approaches.
# Furthermore, this preference
# for specific models neglects the rich landscape
# of existing psychological theories related to emo-
# tions. Emotion is a complex and multifaceted phe-
# nomenon, and various psychological theories offer
# different insights into how emotions are generated,
# expressed, and perceived (Hofmann et al., 2020).
# 5702
# Overlooking these diverse theories means miss-
# ing out on knowledge, valuable perspectives, and
# dimensions of emotion. More recent studies fol-
# low alternative theories of cognitive appraisal of
# events (see Section 3.2) and show their potential
# for emotion classification when encoded in categori-
# cal models. Öhman 2020 also point out that current
# annotation schemes are based on psychological
# theories not primarily focused on text.
# 4.2.
# Inconsistency in Terminology
# Section 3.1 shows the inconsistent terminology
# used in EA. This lack of specificity can obscure
# the related but distinct subtasks. Currently, no dis-
# tinction is made between ‘emotion classification’,
# for example, and ‘emotion prediction’. We generally
# understand classification as a subtask of prediction,
# so these terms might be treated as synonymous.
# We argue that EA should clarify its jargon. Given
# the growing interest in detecting the triggers for
# emotion in NLP, we suggest using the term pre-
# diction to demarcate tasks that are interested in
# emotions before they occur, such as forecasting a
# customer’s frustration during a support chat based
# on contextual cues. One could also make the case
# that emotion classification should refer to classify-
# ing a set of emotions, whereas emotion detection or
# recognition are searching for a specific emotion for
# a specific reason. For example, using NLP for sui-
# cide prevention might involve detecting sadness,
# desperation, or anger. However, it might seem
# odd to say it would involve classifying emotions.
# Mapping EA in NLP using consistent nomencla-
# ture will enable NLP practitioners to focus on fine-
# grained specific tasks since there will be a clear
# goal. It will also highlight gaps in EA for which new
# tasks must emerge.
# 4.3.
# Lack of Interdisciplinarity
# Two issues arise out of the general lack of interdis-
# ciplinary engagement in EA: The first issue was
# already raised by Kusal et al. (2022a), who con-
# cluded that it would be helpful to gain a deeper
# understanding of emotions for the classification
# process. As we showed in Section 3.2, currently,
# EA in NLP relies solely on emotion models and
# frameworks borrowed from psychology. In particu-
# lar, NLP overwhelmingly relies on Ekman’s theory
# from the 1970s. This theory identifies emotions
# with bodily signatures, while Barrett (2017) has em-
# pirically problematized it by stating that emotions
# do not have such signatures and emphasizes the
# importance of considering the context for interpret-
# ing emotions. Additionally, Ekman’s views have
# been conceptually criticized by philosophers who
# argue that emotions possess intentionality, being
# directed towards something, a characteristic not
# adequately addressed in Ekman’s theory.6
# The second issue concerns potential applications
# across fields. Most papers we reviewed here do
# not mention the potential applicability of EA to the
# humanities and social sciences, even though that
# is a fruitful area of development (e.g., digital hu-
# manities). Collaboration between these disciplines
# can lead to innovative research, the development of
# specialized tools, and the integration of emotional
# insights into a broader range of academic studies.
# This interdisciplinary synergy would be mutually
# beneficial, enriching the understanding of human
# emotions and their role in various domains.
# 4.4.
# Demographics and Cultural
# Implications
# Demographic factors such as age, gender, cultural
# background, and socioeconomic status can signifi-
# cantly shape individual differences while express-
# ing and experiencing emotions. Bender and Fried-
# man (2018) call for careful data curation and con-
# scientious reporting of the processes and actors
# involved in corpus creation. More specifically, they
# call for reporting who produced and who annotated
# the data. We note that most papers we reviewed do
# not include a data statement or report demograph-
# ics for either the data creators or the annotators.
# Additionally, when demographic data is collected,
# it is more commonly associated with annotators
# rather than data creators, as observed in prior stud-
# ies ((Troiano et al., 2019; Haider et al., 2020; Ka-
# ...
# notation paradigms for subjective NLP tasks. In
# Proceedings of the 2022 Conference of the North
# American Chapter of the Association for Com-
# putational Linguistics: Human Language Tech-
# nologies, pages 175–190, Seattle, United States.
# Association for Computational Linguistics.
# James A Russell and Albert Mehrabian. 1977. Evi-
# dence for a three-factor theory of emotions. Jour-
# nal of Research in Personality, 11(3):273–294.
# 5709
# Kashfia Sailunaz, Manmeet Dhaliwal, Jon G.
# Rokne, and Reda Alhajj. 2018. Emotion detec-
# tion from text and speech: a survey. Soc. Netw.
# Anal. Min., 8(1):28:1–28:26.
# Anbukkarasi
# Sampath,
# Thenmozhi
# Durairaj,
# Bharathi Raja Chakravarthi, Ruba Priyadharshini,
# Subalalitha Cn, Kogilavani Shanmugavadivel,
# Sajeetha Thavareesan, Sathiyaraj Thangasamy,
# Parameswari Krishnamurthy, Adeep Hande,
# Sean Benhur, Kishore Ponnusamy, and Santhiya
# Pandiyan. 2022. Findings of the shared task on
# emotion analysis in Tamil. In Proceedings of the
# Second Workshop on Speech and Language
# Technologies for Dravidian Languages, pages
# 279–285,
# Dublin,
# Ireland.
# Association
# for
# Computational Linguistics.
# Anvita Saxena, Ashish Khanna, and Deepak Gupta.
# 2020. Emotion recognition and detection meth-
# ods: A comprehensive survey. Journal of Artifi-
# cial Intelligence and Systems, 2(1):53–79.
# Andrea Scarantino and Ronald de Sousa. 2021.
# Emotion. In Edward N. Zalta, editor, The Stanford
# Encyclopedia of Philosophy, Summer 2021 edi-
# tion. Metaphysics Research Lab, Stanford Uni-
# versity.
# Klaus R. Scherer. 1999. Appraisal Theory, chap-
# ter 30. John Wiley & Sons, Ltd.
# Pavlo Seroyizhko, Zhanel Zhexenova, Muham-
# mad Zohaib Shafiq, Fabio Merizzi, Andrea
# Galassi, and Federico Ruggeri. 2022. A sen-
# timent and emotion annotated dataset for bitcoin
# price forecasting based on Reddit posts. In Pro-
# ceedings of the Fourth Workshop on Financial
# Technology and Natural Language Processing
# (FinNLP), pages 203–210, Abu Dhabi, United
# Arab Emirates (Hybrid). Association for Compu-
# tational Linguistics.
# Pragya Singh Tomar, Kirti Mathur, and Ugrasen
# Suman. 2023. Unimodal approaches for emo-
# tion recognition: A systematic review. Cognitive
# Systems Research, 77:94–109.
# Craig A Smith and Phoebe C Ellsworth. 1985. Pat-
# terns of cognitive appraisal in emotion. Journal
# of personality and social psychology, 48(4):813.
# Sanket Sonu,
# Rejwanul Haque,
# Mohammed
# Hasanuzzaman, Paul Stynes, and Pramod
# Pathak. 2022.
# Identifying emotions in code
# mixed hindi-english tweets. In Proceedings of the
# WILDRE-6 Workshop within the 13th Language
# Resources and Evaluation Conference, pages
# 35–41.
# Tiberiu Sosea, Chau Pham, Alexander Tekle,
# Cornelia Caragea, and Junyi Jessy Li. 2022.
# Emotion analysis and detection during COVID-
# 19. In Proceedings of the Thirteenth Language
# Resources and Evaluation Conference, pages
# 6938–6947, Marseille, France. European Lan-
# guage Resources Association.
# Marco Antonio Stranisci, Simona Frenda, Eleonora
# Ceccaldi, Valerio Basile, Rossana Damiano, and
# Viviana Patti. 2022. APPReddit: a corpus of Red-
# dit posts annotated for appraisal. In Proceedings
# of the Thirteenth Language Resources and Eval-
# uation Conference, pages 3809–3818, Marseille,
# France. European Language Resources Associ-
# ation.
# Carlo Strapparava and Rada Mihalcea. 2008.
# Learning to identify emotions in text. In Proceed-
# ings of the 2008 ACM symposium on Applied
# computing, pages 1556–1560.
# Enrica Troiano, Laura Oberländer, and Roman
# Klinger. 2023. Dimensional modeling of emotions
# in text with appraisal theories: Corpus creation,
# annotation reliability, and prediction. Computa-
# tional Linguistics, 49(1):1–72.
# Enrica Troiano, Sebastian Padó, and Roman
# Klinger. 2019.
# Crowdsourcing and validating
# event-focused emotion corpora for German and
# English. In Proceedings of the 57th Annual Meet-
# ing of the Association for Computational Linguis-
# tics, pages 4005–4011, Florence, Italy. Associa-
# tion for Computational Linguistics.
# Elsbeth Turcan, Smaranda Muresan, and Kathleen
# McKeown. 2021. Emotion-infused models for
# explainable psychological stress detection. In
# Proceedings of the 2021 Conference of the North
# American Chapter of the Association for Compu-
# tational Linguistics: Human Language Technolo-
# gies, pages 2895–2909, Online. Association for
# Computational Linguistics.
# Jonathan Turner. 2000. On the origins of human
# emotions: A sociological inquiry into the evolution
# of human affect. Stanford University Press.
# Ali Yadollahi, Ameneh Gholipour Shahraki, and Os-
# mar R. Zaiane. 2017. Current state of text sen-
# timent analysis from opinion to emotion mining.
# ACM Computing Surveys, 50(2).
# Samira Zad and Mark Finlayson. 2020. Systematic
# evaluation of a framework for unsupervised emo-
# tion recognition for narrative text. In Proceedings
# of the First Joint Workshop on Narrative Under-
# standing, Storylines, and Events, pages 26–37,
# Online. Association for Computational Linguis-
# tics.
# 5710
# Sayyed M. Zahiri and Jinho D. Choi. 2017. Emotion
# detection on tv show transcripts with sequence-
# based convolutional neural networks. In AAAI
# Workshops.
# Hongli Zhan, Tiberiu Sosea, Cornelia Caragea, and
# Junyi Jessy Li. 2022. Why do you feel this way?
# summarizing triggers of emotions in social media
# posts. In Proceedings of the 2022 Conference
# on Empirical Methods in Natural Language Pro-
# cessing, pages 9436–9453, Abu Dhabi, United
# Arab Emirates. Association for Computational
# Linguistics.
# Jinming Zhao, Tenggan Zhang, Jingwen Hu,
# Yuchen Liu, Qin Jin, Xinchao Wang, and Haizhou
# Li. 2022. M3ED: Multi-modal multi-scene multi-
# label emotional dialogue database. In Proceed-
# ings of the 60th Annual Meeting of the Associ-
# ation for Computational Linguistics (Volume 1:
# Long Papers), pages 5699–5710, Dublin, Ireland.
# Association for Computational Linguistics.
# Peixiang Zhong, Di Wang, and Chunyan Miao.
# 2019. Knowledge-enriched transformer for emo-
# tion detection in textual conversations. In Pro-
# ceedings of the 2019 Conference on Empirical
# Methods in Natural Language Processing and
# the 9th International Joint Conference on Natural
# Language Processing (EMNLP-IJCNLP), pages
# 165–176, Hong Kong, China. Association for
# Computational Linguistics.
#
# ####################################################################################################
#
#
# Content of Relationships.pdf:
# See this helpsheet and lots of other useful information at www.ntu.ac.uk/wellbeing
#
#
# RELATIONSHIPS
#
# Introduction
#
# Relationships – whether family, friends or intimate relationships with a partner –
# can be a great source of love, pleasure, support and excitement. However they can
# also be a source of grief, anger and anguish if they go wrong. The issue is made
# more relevant for students by the fact that most people in a university are in a
# period of personal change, which can make them feel less sure of what they want
# or how they can expect others to react.
#
# Researchers who have looked into what makes relationships work successfully –
# whether family relationships, friendships or partnerships – tend to come up with
# the same few things:
#
# Acceptance of difference
# People in successful relationships do not try to force the other to be exactly
# like them; they work to accept differences.
#
# Capacity for boundaries
# People are aware that there is a point where they stop and the other person
# begins and that it is unrealistic to expect others to solve all our problems or
# meet all our needs.
#
# Operating mainly in the present
# Once relationships either focus on repeatedly picking over past events, or
# else are based only on the hope that things will be better tomorrow, they
# tend to go wrong.
#
# Respect for individual choice
# It is accepted that each person has the right to decide their own direction
# in life; the relationship then adapts to follow this.
#
# Skill in negotiating
# Once each individual has decided what they want, the couple or family are
# able to work out a fair way to fulfil these different goals.
#
# Sharing positive feelings
# In a couple, this may be sexual intimacy; however it can also just be
# pleasantness and kindness, as it is in a family.
#
# It might be that a relationship requires quite a lot of individual skill for this. It is
# comforting to consider the research of John Bowlby on attachment. He concluded
# that human beings are innately social and tend instinctively to know how to form
# close attachments to others. Relationship problems often arise not because we
# never learned what to do, but because we have lost touch with this instinctive good
# sense and become over-anxious about our relationships.
#
# We may have been out of touch with our ability to make successful relationships
# for so long that we may doubt if we ever had it - however most people seem able
# to recover these skills if they put their mind to it.
#
# Much work on improving a relationship can start with the individual. If one person
# is clear and reasoned about what they want and more consistent about how they
# ask for it, the whole relationship can begin to be put on a different basis.
#
#
#
#
# Dealing with Problems in your Family
#
# Family problems can be difficult as there might be a lot of people involved. Also
# most of us are not used to looking at our families objectively. However a bit of
# reflection and analysis can take the heat out of a lot of difficult situations.
#
# If you have found yourself in a disagreement with your family about something:
#
# 1. Try and think objectively about what you are trying to achieve. Give yourself
# the benefit of the doubt and attribute the best motives to your behaviour. If at
# this point you realise you’re doing the wrong thing, you might want to make a
# strategic withdrawal/stop there/consider apologising!  However let’s assume
# you end up convinced you know what you are doing and you have a bit of
# evidence to back this up.  If so:
#
# 2. Think about why your family is disagreeing with you. There is probably more
# than one reason. Maybe they don’t understand your plan; maybe they had a
# course of action decided for you; maybe they have some worries and anxieties
# of their own. Make a real effort to think yourself into their shoes even though
# their behaviour may be very frustrating to you. Imagine discussing the question
# with them – think of what you might say and how they might reply. When
# you’ve thought of what might be worrying them, think creatively of ways of
# reassuring them. If it helps, make a list of their worries and reassurances.
#
# 3. Find some way of discussing it. That’s easy if your family are talkers, but many
# families aren’t. However you can still find an opportunity to calmly mention your
# plans, to give a few examples of others who have done the same, to reassure
# their fears and sympathies with their disappointment. You may have to drop
# your points into the conversation over a period of time. Don’t expect a miracle
# – people rarely change their opinions overnight. Don’t feel you have to have a
# total agreement; stop the discussion while the going is still good and come back
# to it a few days later. If they see you’re serious and that some of their worries
# have been considered they will probably be a bit more agreeable the next time.
#
# This is obviously a very simple example, but a similar approach can help in many
# situations.
#
#
# Dealing with Problems in Your Personal Relationships
#
# Problems can arise from a large number of sources and it can frequently need some
# care to help disentangle the mixture of influences. These problems can be
# intensified by the pressures from others to form or end a relationship and the
# general pressures from the media which give an idealised view of couples (which
# is often at odds with the reality many people experience).
#
# Here are some simple guidelines:
#
# Do you know what you are looking for in a relationship?
# There are many different reasons for entering into a relationship – for
# companionship; for sexual experience; to have a long-term partner; to create a
# family and so on. Do you know what you are looking for? Have you discussed this
# with your partner?
#
#
#
#
#
# Are you asking too much or expecting too little from your relationship?
# A good relationship can provide support, sexual expression, companionship and
# eventually an opportunity to build a joint life. If you are looking to it to provide
# more than this – for example to give you a sense of purpose and worth or protect
# you from some deep personal fear – you may be trying to get a partner to provide
# things that in fact only you can achieve. If, on the other hand, a relationship brings
# you continual grief, stress or pain, you may be accepting for yourself a far lower
# level of interaction than you have a right to expect. In particular no-one deserves
# to be on the receiving end of physical or sexual violence, or emotional/psychological
# abuse/controlling behaviour. Do look for the support you need to change or end a
# relationship if abuse is happening to you.
#
# How you get a model for the relationship you are trying to build?
# Many people find it helpful to picture a relationship that they admire and to which
# they wish to aspire. It may be the relationship of someone you know or a fictional
# one. Consider how the people in this relationship resolve differences and difficulties.
# Finding such models can be a particularly important task whether you are
# heterosexual, lesbian, gay, or bisexual same-gender couples.
#
# Can you talk about problems?
# In all relationships there are going to be times of serious disagreement, where a
# conflict of interests has to be resolved. This doesn’t mean there is something wrong
# with the relationship. However, arguing the point out and reaching agreement does
# take a bit of skill and practice.
#
# If you are not in the habit of talking in your relationship, it might be interesting
# /helpful to give it a try.  Relationships can be well worth exploring.
#
# Golden rules for arguing constructively
#
# DO:
# 
# Know why you are arguing before you start – be specific
# 
# Devote some time to resolving the problem
# 
# Sit down and make eye contact
# 
# Speak personally about what you feel
# 
# Acknowledge when the other person makes a valid point
# 
# Agree to differ if you cannot agree
# 
# Stick to the matter in hand
# 
# Cease arguing and separate if there is any likelihood of violence
#
# TRY NOT TO:
# 
# Behave aggressively or disrespectfully
# 
# Deliberately hurt the other person’s feelings
# 
# Generalise
# 
# Bring up old unresolved disputes
# 
# Walk away without deciding when discussion will be resumed (unless
# violence threatens)
# 
# Bring other people’s opinions in
# 
# Argue about something for more than an hour
# 
# Argue late at night or after drinking
#
# There is a great range of relationships and of relationship difficulties.
# Counselling can be a help in allowing you to clarify and resolve complex
# relationship problems.
#
#
#
#
#
# Books/Agencies
#
# The Relate Guide to Better Relationships by Sarah Litvinoff, Vermilion. (A
# comprehensive and easy to read guide to all aspects of couple relationships.
# Includes many case histories and a lot of self-help exercises.)
#
# The Relate Guide to Sex in Loving Relationships by Sarah Litvinoff, Vermilion.
# (Covers a wealth of sexual difficulties and how to resolve them).
#
# STOP Arguing START Talking: The 10 Point Plan for Couples in Conflict by Susan
# Quilliam, Vermilion.
#
# Boundaries and Relationships: Knowing, Protecting and Enjoying the Self by
# Charles L. Whitfield, HCI.
#
# Relate - offers help to couples and family members having relationship problems.
# Tel: 0300 100 1234
# Website: www.relate.org.uk
#
# Families and How to Survive Them by Robin Skynner and John Cleese, Vermilion.
# (A lighthearted book which nonetheless explores many of the dynamics of family
# life well.)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NTUSSSSCS/July2017
#
# ####################################################################################################

# %%
mpreprocessed_documents = []
for doc in mdocs:
    preprocessor = TextPreprocessing(doc)
    mpreprocessed_documents.append(preprocessor.fit())

# Output the preprocessed documents
for i, doc in enumerate(mpreprocessed_documents):
    print(f"Document {i+1}: {doc}")
# Out:
# Document 1: {'prevents', 'closer', 'advancing', 'roles', 'sack', 'whether', 'thats', 'passing', 'next', 'safety', 'come', 'alternative', 'break', 'accidentally', 'hit', 'another', 'block', 'certain', 'time', 'th', 'keep', 'main', 'use', 'getsor', 'team', 'give', 'typically', 'interception', 'need', 'officials', 'spotted', 'bounds', 'free', 'grab', 'rushes', 'lateral', 'official', 'first', 'hike', 'blocking', 'holds', 'audible', 'changes', 'recover', 'make', 'umpire', 'someone', 'thrown', 'overtime', 'touchdown', 'position', 'legally', 'decide', 'runs', 'linemen', 'receiver', 'snap', 'encroachment', 'snaps', 'crossbar', 'kicker', 'blitz', 'air', 'upon', 'opponent', 'area', 'check', 'prevent', 'halfback', 'one', 'timing', 'rush', 'fumble', 'retainspossession', 'tackles', 'three', 'blockers', 'catching', 'goes', 'cornerbacks', 'whoever', 'four', 'usual', 'half', 'stop', 'wide', 'hold', 'standing', 'diving', 'incomplete', 'fair', 'part', 'measured', 'way', 'purposely', 'grasping', 'fourth', 'meant', 'follow', 'crossing', 'placekicker', 'ground', 'difficult', 'look', 'begin', 'moves', 'quarterback', 'held', 'stops', 'zone', 'work', 'anyone', 'begins', 'enter', 'touchdowns', 'ball', 'uniform', 'scrimmage', 'pass', 'backs', 'also', 'leader', 'avoid', 'loose', 'recovers', 'markings', 'two', 'goalpost', 'intercepting', 'blocks', 'opportunity', 'tackle', 'kickoff', 'personal', 'raising', 'turnovers', 'recoveries', 'guards', 'agreed', 'referee', 'knees', 'making', 'post', 'toward', 'bay', 'help', 'rules', 'following', 'times', 'intentional', 'signal', 'needed', 'units', 'teams', 'little', 'quarters', 'legs', 'throwing', 'plays', 'fans', 'safeties', 'punt', 'helpful', 'stand', 'involved', 'fakes', 'eluding', 'neutral', 'actually', 'handle', 'cover', 'touch', 'bumpandrun', 'rather', 'backfield', 'interceptions', 'turnover', 'foul', 'man', 'drive', 'snapped', 'kneel', 'together', 'protected', 'special', 'reaches', 'usually', 'football', 'though', 'hits', 'picks', 'advance', 'ends', 'possible', 'passer', 'structure', 'regain', 'qb', 'confuse', 'causes', 'starts', 'nyfl', 'want', 'considered', 'take', 'point', 'lineman', 'bringing', 'getting', 'kickoffs', 'forward', 'regardless', 'gain', 'beyond', 'offensive', 'score', 'back', 'include', 'additional', 'player', 'new', 'fails', 'offenses', 'allowed', 'playmaker', 'may', 'turn', 'complete', 'per', 'possession', 'sign', 'signals', 'intent', 'headtohead', 'goal', 'important', 'offense', 'linebackers', 'divided', 'drops', 'penalty', 'played', 'referred', 'forth', 'much', 'second', 'whichever', 'called', 'play', 'defensive', 'scored', 'uprights', 'officiating', 'pushed', 'defenders', 'loses', 'moving', 'defense', 'field', 'yardage', 'yards', 'defender', 'job', 'games', 'towards', 'add', 'successfully', 'many', 'probably', 'kicks', 'nose', 'throw', 'gaining', 'stands', 'move', 'pocket', 'definitions', 'front', 'basics', 'defend', 'takes', 'downs', 'white', 'linesman', 'must', 'minute', 'least', 'points', 'arms', 'grounding', 'aggressive', 'hands', 'game', 'code', 'moved', 'around', 'sits', 'kicking', 'earns', 'youre', 'defenses', 'long', 'passes', 'side', 'progress', 'tries', 'measures', 'tackled', 'unless', 'series', 'set', 'notify', 'fullback', 'spot', 'happens', 'cause', 'bodies', 'playaction', 'touchback', 'decides', 'extra', 'end', 'action', 'sacked', 'scoring', 'battles', 'gets', 'either', 'catch', 'handing', 'tee', 'center', 'brings', 'caught', 'running', 'halftime', 'loudly', 'track', 'backwards', 'finger', 'returner', 'carrier', 'pointaftertouchdown', 'sometimes', 'placed', 'chances', 'ballgets', 'return', 'forces', 'catches', 'waving', 'fieldby', 'players', 'throws', 'injury', 'body', 'conversion', 'guard', 'scrambling', 'run', 'switch', 'movement', 'away', 'separated', 'kick', 'start', 'occurs', 'terms', 'ways', 'place', 'kicked', 'situations', 'hand', 'yard', 'calls', 'via', 'playing', 'prior', 'get', 'section', 'holding', 'object', 'separate', 'push', 'goals', 'men', 'nickel', 'onto', ' ...
# Document 2: {'leather', 'choose', 'side', 'always', 'bounced', 'alleys', 'still', 'foot', 'base', 'exceptions', 'ball', 'c', 'six', 'sent', 'deuce', 'purpose', 'toss', 'perpendicular', 'strings', 'set', 'thereafter', 'near', 'next', 'score', 'back', 'shot', 'good', 'best', 'servers', 'baseline', 'player', 'hit', 'stroke', 'two', 'forty', 'five', 'falls', 'sets', 'goof', 'court', 'tie', 'lines', 'time', 'may', 'error', 'th', 'change', 'win', 'keep', 'main', 'boundaries', 'number', 'scoring', 'possession', 'team', 'thirty', 'winning', 'example', 'correct', 'center', 'downward', 'call', 'third', 'mark', 'served', 'question', 'nothing', 'outside', 'attempting', 'adout', 'rally', 'across', 'facing', 'match', 'lands', 'track', 'rd', 'racket', 'hitting', 'first', 'sidelines', 'zero', 'throughout', 'explanation', 'rules', 'calling', 'closed', 'following', 'boundary', 'forth', 'coin', 'singles', 'changing', 'chances', 'second', 'sunny', 'service', 'beginning', 'surface', 'unit', 'times', 'saves', 'put', 'called', 'flat', 'alternate', 'play', 'opposite', 'b', 'apply', 'players', 'wins', 'st', 'serves', 'aluminum', 'serve', 'diagonal', 'loses', 'let', 'maintained', 'replayed', 'helps', 'receiver', 'love', 'anywhere', 'forehand', 'arching', 'ahead', 'grip', 'equal', 'face', 'trim', 'fifteen', 'iv', 'games', 'diagonally', 'thought', 'start', 'legal', 'odd', 'replays', 'e', 'air', 'upward', 'handle', 'includes', 'right', 'order', 'tennis', 'doubles', 'sides', 'top', 'backhand', 'enclosing', 'place', 'total', 'guide', 'succession', 'etiquette', 'covered', 'hand', 'one', 'adin', 'advantage', 'vi', 'touches', 'handed', 'wooden', 'double', 'fall', 'strike', 'volley', 'three', 'small', 'alley', 'inside', 'stringing', 'get', 'gripped', 'holding', 'shaft', 'four', 'head', 'throat', 'turned', 'striking', 'balls', 'lob', 'iii', 'bottom', 'interference', 'people', 'say', 'circumstance', 'fair', 'part', 'must', 'used', 'line', 'pointgameprovided', 'consecutive', 'terminology', 'least', 'v', 'fault', 'hint', 'study', 'way', 'go', 'ect', 'periods', 'every', 'points', 'net', 'left', 'server', 'fourth', 'game', 'behind', 'causes', 'equipment', 'feet', 'want', 'partners', 'delivery', 'ground', 'tips', 'begin', 'faults', 'etc', 'courts', 'sun', 'frame', 'open', 'point', 'continue', 'misses', 'earns', 'fore', 'ready', 'high', 'shall', 'steeping', 'long', 'ii', 'spin', 'nd'}
# Document 3: {'works', 'european', 'aspects', 'intentionality', 'scarcity', 'scene', 'endeavors', 'evolution', 'graziotin', 'whether', 'jective', 'tenggan', 'pluralistic', 'alimuddin', 'jonathan', 'alternative', 'selfcitations', 'haque', 'therefore', 'initiative', 'giuseppe', 'focus', 'diversity', 'john', 'subtask', 'th', 'main', 'winfried', 'aida', 'focuses', 'affect', 'ference', 'surpassing', 'mod', 'source', 'ethnicity', 'ings', 'lar', 'valuable', 'los', 'sebastian', 'cre', 'predominantly', 'acheampong', 'majority', 'utterance', 'feature', 'shruti', 'texts', 'teresa', 'stock', 'sunset', 'pairs', 'nal', 'moreover', 'publishing', 'beginning', 'interpret', 'humour', 'large', 'literature', 'often', 'signatures', 'myriam', 'stan', 'history', 'dit', 'haizhou', 'ieee', 'institute', 'broad', 'demarcates', 'cues', 'thinking', 'given', 'associ', 'data', 'corpus', 'ali', 'synthesising', 'kirti', 'overview', 'citation', 'variations', 'nent', 'recog', 'hiri', 'sungjoon', 'nagahara', 'situation', 'advances', 'narrative', 'domains', 'exhibit', 'artifi', 'old', 'prabhakaran', 'consensus', 'machinery', 'growth', 'one', 'chau', 'argue', 'liter', 'categorized', 'subalalitha', 'niu', 'available', 'attention', 'instance', 'likert', 'flor', 'marinucci', 'spanish', 'processes', 'berlin', 'says', 'inherently', 'philipp', 'joint', 'mostly', 'com', 'w', 'sons', 'chang', 'standing', 'email', 'simona', 'conceptualization', 'room', 'appearance', 'sailunaz', 'used', 'news', 'im', 'stress', 'appli', 'feminist', 'samuel', 'ical', 'sns', 'farreaching', 'level', 'spaces', 'ground', 'categorical', 'kuu', 'miriam', 'marketing', 'guages', 'world', 'preference', 'labelled', 'dimensional', 'anil', 'decade', 'choi', 'frameworks', 'dhn', 'matters', 'pappas', 'kocon', 'pass', 'dubrovnik', 'zohaib', 'recommendations', 'mapping', 'provides', 'means', 'natural', 'two', 'gopendra', 'psychologist', 'labeled', 'ceedings', 'inquiry', 'quent', 'information', 'ment', 'number', 'signifi', 'philosophical', 'alba', 'poems', 'gual', 'po', 'ja', 'degree', 'ies', 'interdisciplinarity', 'unique', 'humanities', 'engaging', 'responses', 'guage', 'zero', 'already', 'crowdsourcing', 'vides', 'page', 'cases', 'risk', 'unit', 'personality', 'cial', 'reveals', 'trends', 'rel', 'woodhead', 'eval', 'tailored', 'plicit', 'annotated', 'andrew', 'marking', 'helpful', 'indi', 'pandiyan', 'poor', 'contrasting', 'mutually', 'luigi', 'shafiq', 'ireland', 'hazarika', 'pan', 'pandemic', 'os', 'report', 'zhexenova', 'disciplinarity', 'seem', 'gonzlez', 'mixed', 'avoiding', 'knowledgebased', 'gender', 'noriko', 'hman', 'economics', 'evoked', 'kawahara', 'xinchao', 'bel', 'proves', 'narra', 'references', 'cn', 'anxiety', 'chap', 'pragya', 'op', 'stranisci', 'amandacercas', 'r', 'ican', 'tinction', 'directed', 'multilabel', 'views', 'structure', 'identification', 'anal', 'gustave', 'timodal', 'context', 'frequency', 'stynes', 'bender', 'contrast', 'orleans', 'mswahili', 'etc', 'exploring', 'frame', 'gives', 'public', 'shown', 'relation', 'guilty', 'mit', 'jectivity', 'sociodemographics', 'adapta', 'curry', 'russell', 'anthology', 'fine', 'become', 'rottger', 'addressed', 'ciation', 'gain', 'anticipation', 'six', 'batya', 'caragea', 'ca', 'gen', 'philosophy', 'oppor', 'innovative', 'offensive', 'soujanya', 'ka', 'additional', 'friedman', 'well', 'nunoomensah', 'michelsen', 'disregard', 'considerations', 'annotating', 'choosing', 'perception', 'estimation', 'regulation', 'generated', 'meaningful', 'sign', 'opinion', 'emnlpijcnlp', 'eventfocused', 'ghosal', 'aware', 'third', 'nakashima', 'detailed', 'salud', 'mathur', 'receives', 'ekmans', 'dismissed', 'ellsworth', 'urea', 'years', 'michael', 'particular', 'suspense', 'except', 'jimnezzafra', 'ekman', 'alexander', 'emotional', 'andrade', 'negative', 'sue', 'lopez', 'representations', 'italy', 'origins', 'frequent', 'interested', 'dealing', 'cc', 'mika', 'demarcate', 'describing', 'qin', 'encoded', 'nuance', 'emphasizes', 'meet', 'kishore', 'descriptive', ' ...
# Document 4: {'sexual', 'asking', 'aspects', 'still', 'whole', 'human', 'discussion', 'support', 'purpose', 'skynner', 'disputes', 'plan', 'resolved', 'acceptance', 'others', 'course', 'whether', 'thats', 'sympathies', 'next', 'come', 'histories', 'positive', 'bowlby', 'persons', 'focus', 'realise', 'partner', 'university', 'adapts', 'john', 'time', 'change', 'helpsheet', 'looking', 'motives', 'susan', 'unresolved', 'late', 'give', 'source', 'ever', 'need', 'lots', 'happening', 'period', 'likelihood', 'disagreement', 'finding', 'person', 'easy', 'wrong', 'reaching', 'worth', 'noone', 'us', 'large', 'put', 'mainly', 'mixture', 'ability', 'often', 'couple', 'recover', 'make', 'someone', 'sit', 'based', 'present', 'decide', 'lost', 'later', 'experience', 'list', 'disrespectfully', 'relationships', 'lot', 'relationship', 'effort', 'right', 'old', 'peoples', 'reassurances', 'interests', 'gay', 'one', 'practice', 'cease', 'intimate', 'argue', 'aggressively', 'plans', 'heat', 'stop', 'joint', 'partnerships', 'feelings', 'looked', 'fair', 'drinking', 'acknowledge', 'lesbian', 'used', 'accepted', 'media', 'stress', 'way', 'approach', 'fictional', 'benefit', 'nonetheless', 'operating', 'constructively', 'resumed', 'follow', 'level', 'fulfil', 'sarah', 'difficult', 'begin', 'look', 'capacity', 'form', 'improving', 'cleese', 'exercises', 'never', 'work', 'reassure', 'devote', 'continual', 'begins', 'allowing', 'relevant', 'decided', 'quite', 'also', 'comprehensive', 'lets', 'information', 'opportunity', 'behaviour', 'personal', 'agreement', 'particularly', 'emotionalpsychological', 'matter', 'number', 'evidence', 'abuse', 'arguing', 'companionship', 'social', 'expecting', 'wwwrelateorguk', 'booksagencies', 'quilliam', 'creatively', 'withdrawalstop', 'kindness', 'issue', 'thing', 'fear', 'youve', 'help', 'rules', 'going', 'skills', 'times', 'like', 'needs', 'strategic', 'discussing', 'individual', 'reassuring', 'little', 'aspire', 'sex', 'disagreeing', 'speak', 'valid', 'helpful', 'helps', 'picking', 'calmly', 'differ', 'ntusssscsjuly', 'involved', 'talk', 'difference', 'learned', 'wwwntuacukwellbeing', 'objectively', 'thereconsider', 'create', 'intimacy', 'includes', 'clarify', 'less', 'touch', 'hurt', 'protecting', 'seem', 'beings', 'influences', 'frequently', 'might', 'violence', 'expect', 'introduction', 'idealised', 'maybe', 'far', 'else', 'though', 'couples', 'people', 'hour', 'things', 'drop', 'go', 'grief', 'behave', 'relate', 'dont', 'hope', 'assume', 'self', 'picture', 'want', 'wish', 'read', 'exploring', 'considered', 'take', 'point', 'instinctively', 'become', 'hci', 'eye', 'comforting', 'offers', 'mention', 'events', 'consider', 'odds', 'back', 'good', 'best', 'well', 'miracle', 'innately', 'similar', 'life', 'vermilion', 'reflection', 'sources', 'arise', 'may', 'interesting', 'react', 'charles', 'aware', 'talking', 'personally', 'direction', 'respect', 'important', 'models', 'loving', 'counselling', 'tel', 'families', 'obviously', 'abusecontrolling', 'walk', 'particular', 'researchers', 'negotiating', 'differences', 'much', 'family', 'reasons', 'care', 'anguish', 'pain', 'expression', 'conversation', 'think', 'dealing', 'sharing', 'attachment', 'robin', 'attachments', 'meet', 'bring', 'enjoying', 'longterm', 'frustrating', 'simple', 'students', 'clear', 'problem', 'exactly', 'tend', 'accept', 'total', 'guide', 'successfully', 'serious', 'worries', 'many', 'explores', 'past', 'different', 'probably', 'talkers', 'makes', 'survive', 'choice', 'days', 'force', 'entering', 'real', 'protect', 'complex', 'attribute', 'skill', 'say', 'doesnt', 'bisexual', 'covers', 'specific', 'friends', 'pleasantness', 'points', 'intensified', 'consistent', 'shoes', 'know', 'disentangle', 'heterosexual', 'anger', 'lighthearted', 'youre', 'general', 'analysis', 'long', 'model', 'case', 'interaction', 'samegender', 'apologising', 'stick', 'admire', 'ask', 'golden', 'unless', 'understand', 'requires', 'physical', 'opinions', 'reasoned', 'repeatedly', 'o ...

# %%
tf_list = [compute_tf(doc) for doc in mpreprocessed_documents]
print(tf_list)
# Out:
# [{'prevents': 0.002457002457002457, 'closer': 0.002457002457002457, 'advancing': 0.002457002457002457, 'roles': 0.002457002457002457, 'sack': 0.002457002457002457, 'whether': 0.002457002457002457, 'thats': 0.002457002457002457, 'passing': 0.002457002457002457, 'next': 0.002457002457002457, 'safety': 0.002457002457002457, 'come': 0.002457002457002457, 'alternative': 0.002457002457002457, 'break': 0.002457002457002457, 'accidentally': 0.002457002457002457, 'hit': 0.002457002457002457, 'another': 0.002457002457002457, 'block': 0.002457002457002457, 'certain': 0.002457002457002457, 'time': 0.002457002457002457, 'th': 0.002457002457002457, 'keep': 0.002457002457002457, 'main': 0.002457002457002457, 'use': 0.002457002457002457, 'getsor': 0.002457002457002457, 'team': 0.002457002457002457, 'give': 0.002457002457002457, 'typically': 0.002457002457002457, 'interception': 0.002457002457002457, 'need': 0.002457002457002457, 'officials': 0.002457002457002457, 'spotted': 0.002457002457002457, 'bounds': 0.002457002457002457, 'free': 0.002457002457002457, 'grab': 0.002457002457002457, 'rushes': 0.002457002457002457, 'lateral': 0.002457002457002457, 'official': 0.002457002457002457, 'first': 0.002457002457002457, 'hike': 0.002457002457002457, 'blocking': 0.002457002457002457, 'holds': 0.002457002457002457, 'audible': 0.002457002457002457, 'changes': 0.002457002457002457, 'recover': 0.002457002457002457, 'make': 0.002457002457002457, 'umpire': 0.002457002457002457, 'someone': 0.002457002457002457, 'thrown': 0.002457002457002457, 'overtime': 0.002457002457002457, 'touchdown': 0.002457002457002457, 'position': 0.002457002457002457, 'legally': 0.002457002457002457, 'decide': 0.002457002457002457, 'runs': 0.002457002457002457, 'linemen': 0.002457002457002457, 'receiver': 0.002457002457002457, 'snap': 0.002457002457002457, 'encroachment': 0.002457002457002457, 'snaps': 0.002457002457002457, 'crossbar': 0.002457002457002457, 'kicker': 0.002457002457002457, 'blitz': 0.002457002457002457, 'air': 0.002457002457002457, 'upon': 0.002457002457002457, 'opponent': 0.002457002457002457, 'area': 0.002457002457002457, 'check': 0.002457002457002457, 'prevent': 0.002457002457002457, 'halfback': 0.002457002457002457, 'one': 0.002457002457002457, 'timing': 0.002457002457002457, 'rush': 0.002457002457002457, 'fumble': 0.002457002457002457, 'retainspossession': 0.002457002457002457, 'tackles': 0.002457002457002457, 'three': 0.002457002457002457, 'blockers': 0.002457002457002457, 'catching': 0.002457002457002457, 'goes': 0.002457002457002457, 'cornerbacks': 0.002457002457002457, 'whoever': 0.002457002457002457, 'four': 0.002457002457002457, 'usual': 0.002457002457002457, 'half': 0.002457002457002457, 'stop': 0.002457002457002457, 'wide': 0.002457002457002457, 'hold': 0.002457002457002457, 'standing': 0.002457002457002457, 'diving': 0.002457002457002457, 'incomplete': 0.002457002457002457, 'fair': 0.002457002457002457, 'part': 0.002457002457002457, 'measured': 0.002457002457002457, 'way': 0.002457002457002457, 'purposely': 0.002457002457002457, 'grasping': 0.002457002457002457, 'fourth': 0.002457002457002457, 'meant': 0.002457002457002457, 'follow': 0.002457002457002457, 'crossing': 0.002457002457002457, 'placekicker': 0.002457002457002457, 'ground': 0.002457002457002457, 'difficult': 0.002457002457002457, 'look': 0.002457002457002457, 'begin': 0.002457002457002457, 'moves': 0.002457002457002457, 'quarterback': 0.002457002457002457, 'held': 0.002457002457002457, 'stops': 0.002457002457002457, 'zone': 0.002457002457002457, 'work': 0.002457002457002457, 'anyone': 0.002457002457002457, 'begins': 0.002457002457002457, 'enter': 0.002457002457002457, 'touchdowns': 0.002457002457002457, 'ball': 0.002457002457002457, 'uniform': 0.002457002457002457, 'scrimmage': 0.002457002457002457, 'pass': 0.002457002457002457, 'backs': 0.002457002457002457, 'also': 0.002457002457002457, 'leader': 0.002457002457002457, 'avoid': 0.002457002457002457, 'loose': 0.002457002457002457, 'recovers' ...

# %%
idf = compute_idf(mpreprocessed_documents)
print(idf)
# Out:
# {'works': 1.916290731874155, 'sexual': 1.916290731874155, 'european': 1.916290731874155, 'aspects': 1.5108256237659907, 'closer': 1.916290731874155, 'intentionality': 1.916290731874155, 'scarcity': 1.916290731874155, 'scene': 1.916290731874155, 'endeavors': 1.916290731874155, 'evolution': 1.916290731874155, 'skynner': 1.916290731874155, 'acceptance': 1.916290731874155, 'graziotin': 1.916290731874155, 'whether': 1.2231435513142097, 'thats': 1.5108256237659907, 'jective': 1.916290731874155, 'tenggan': 1.916290731874155, 'safety': 1.916290731874155, 'come': 1.5108256237659907, 'pluralistic': 1.916290731874155, 'alimuddin': 1.916290731874155, 'jonathan': 1.916290731874155, 'alternative': 1.5108256237659907, 'selfcitations': 1.916290731874155, 'haque': 1.916290731874155, 'accidentally': 1.916290731874155, 'bowlby': 1.916290731874155, 'therefore': 1.916290731874155, 'hit': 1.5108256237659907, 'initiative': 1.916290731874155, 'giuseppe': 1.916290731874155, 'focus': 1.5108256237659907, 'diversity': 1.916290731874155, 'realise': 1.916290731874155, 'john': 1.5108256237659907, 'subtask': 1.916290731874155, 'th': 1.2231435513142097, 'main': 1.2231435513142097, 'winfried': 1.916290731874155, 'aida': 1.916290731874155, 'focuses': 1.916290731874155, 'affect': 1.916290731874155, 'thirty': 1.916290731874155, 'ference': 1.916290731874155, 'surpassing': 1.916290731874155, 'mod': 1.916290731874155, 'source': 1.5108256237659907, 'ethnicity': 1.916290731874155, 'ings': 1.916290731874155, 'lar': 1.916290731874155, 'valuable': 1.916290731874155, 'los': 1.916290731874155, 'sebastian': 1.916290731874155, 'cre': 1.916290731874155, 'predominantly': 1.916290731874155, 'acheampong': 1.916290731874155, 'majority': 1.916290731874155, 'utterance': 1.916290731874155, 'feature': 1.916290731874155, 'shruti': 1.916290731874155, 'texts': 1.916290731874155, 'teresa': 1.916290731874155, 'official': 1.916290731874155, 'stock': 1.916290731874155, 'sunset': 1.916290731874155, 'pairs': 1.916290731874155, 'wrong': 1.916290731874155, 'blocking': 1.916290731874155, 'nal': 1.916290731874155, 'worth': 1.916290731874155, 'moreover': 1.916290731874155, 'publishing': 1.916290731874155, 'beginning': 1.5108256237659907, 'us': 1.916290731874155, 'interpret': 1.916290731874155, 'humour': 1.916290731874155, 'audible': 1.916290731874155, 'large': 1.5108256237659907, 'literature': 1.916290731874155, 'mixture': 1.916290731874155, 'often': 1.5108256237659907, 'signatures': 1.916290731874155, 'myriam': 1.916290731874155, 'stan': 1.916290731874155, 'sit': 1.916290731874155, 'touchdown': 1.916290731874155, 'history': 1.916290731874155, 'dit': 1.916290731874155, 'position': 1.916290731874155, 'haizhou': 1.916290731874155, 'ieee': 1.916290731874155, 'legally': 1.916290731874155, 'institute': 1.916290731874155, 'broad': 1.916290731874155, 'demarcates': 1.916290731874155, 'cues': 1.916290731874155, 'thinking': 1.916290731874155, 'given': 1.916290731874155, 'anywhere': 1.916290731874155, 'associ': 1.916290731874155, 'data': 1.916290731874155, 'corpus': 1.916290731874155, 'ali': 1.916290731874155, 'synthesising': 1.916290731874155, 'kirti': 1.916290731874155, 'overview': 1.916290731874155, 'citation': 1.916290731874155, 'variations': 1.916290731874155, 'nent': 1.916290731874155, 'recog': 1.916290731874155, 'hiri': 1.916290731874155, 'sungjoon': 1.916290731874155, 'snaps': 1.916290731874155, 'crossbar': 1.916290731874155, 'nagahara': 1.916290731874155, 'legal': 1.916290731874155, 'situation': 1.916290731874155, 'advances': 1.916290731874155, 'air': 1.5108256237659907, 'narrative': 1.916290731874155, 'domains': 1.916290731874155, 'exhibit': 1.916290731874155, 'artifi': 1.916290731874155, 'right': 1.5108256237659907, 'old': 1.5108256237659907, 'prevent': 1.916290731874155, 'prabhakaran': 1.916290731874155, 'consensus': 1.916290731874155, 'machinery': 1.916290731874155, 'growth': 1.916290731874155, 'one': 1.0, 'chau': 1.916290731874155, 'timing': 1.916290731874155, 'advantage': 1.916290731874155, 'i ...

# %%
tfidf_list = [compute_tfidf(tf, idf) for tf in tf_list]
print(tfidf_list)
# Out:
# [{'prevents': 0.004708331036545835, 'closer': 0.004708331036545835, 'advancing': 0.004708331036545835, 'roles': 0.0037121022696953087, 'sack': 0.004708331036545835, 'whether': 0.0030052667108457242, 'thats': 0.0037121022696953087, 'passing': 0.004708331036545835, 'next': 0.0030052667108457242, 'safety': 0.004708331036545835, 'come': 0.0037121022696953087, 'alternative': 0.0037121022696953087, 'break': 0.004708331036545835, 'accidentally': 0.004708331036545835, 'hit': 0.0037121022696953087, 'another': 0.0037121022696953087, 'block': 0.004708331036545835, 'certain': 0.0037121022696953087, 'time': 0.002457002457002457, 'th': 0.0030052667108457242, 'keep': 0.0030052667108457242, 'main': 0.0030052667108457242, 'use': 0.0037121022696953087, 'getsor': 0.004708331036545835, 'team': 0.0037121022696953087, 'give': 0.0037121022696953087, 'typically': 0.004708331036545835, 'interception': 0.004708331036545835, 'need': 0.0030052667108457242, 'officials': 0.004708331036545835, 'spotted': 0.004708331036545835, 'bounds': 0.004708331036545835, 'free': 0.004708331036545835, 'grab': 0.004708331036545835, 'rushes': 0.004708331036545835, 'lateral': 0.004708331036545835, 'official': 0.004708331036545835, 'first': 0.0030052667108457242, 'hike': 0.004708331036545835, 'blocking': 0.004708331036545835, 'holds': 0.004708331036545835, 'audible': 0.004708331036545835, 'changes': 0.004708331036545835, 'recover': 0.0037121022696953087, 'make': 0.0030052667108457242, 'umpire': 0.004708331036545835, 'someone': 0.0030052667108457242, 'thrown': 0.004708331036545835, 'overtime': 0.004708331036545835, 'touchdown': 0.004708331036545835, 'position': 0.004708331036545835, 'legally': 0.004708331036545835, 'decide': 0.0037121022696953087, 'runs': 0.004708331036545835, 'linemen': 0.004708331036545835, 'receiver': 0.0037121022696953087, 'snap': 0.004708331036545835, 'encroachment': 0.004708331036545835, 'snaps': 0.004708331036545835, 'crossbar': 0.004708331036545835, 'kicker': 0.004708331036545835, 'blitz': 0.004708331036545835, 'air': 0.0037121022696953087, 'upon': 0.0037121022696953087, 'opponent': 0.004708331036545835, 'area': 0.0037121022696953087, 'check': 0.004708331036545835, 'prevent': 0.004708331036545835, 'halfback': 0.004708331036545835, 'one': 0.002457002457002457, 'timing': 0.004708331036545835, 'rush': 0.004708331036545835, 'fumble': 0.004708331036545835, 'retainspossession': 0.004708331036545835, 'tackles': 0.004708331036545835, 'three': 0.0030052667108457242, 'blockers': 0.004708331036545835, 'catching': 0.004708331036545835, 'goes': 0.0037121022696953087, 'cornerbacks': 0.004708331036545835, 'whoever': 0.004708331036545835, 'four': 0.0030052667108457242, 'usual': 0.004708331036545835, 'half': 0.004708331036545835, 'stop': 0.0037121022696953087, 'wide': 0.004708331036545835, 'hold': 0.004708331036545835, 'standing': 0.0037121022696953087, 'diving': 0.004708331036545835, 'incomplete': 0.004708331036545835, 'fair': 0.0030052667108457242, 'part': 0.0030052667108457242, 'measured': 0.004708331036545835, 'way': 0.002457002457002457, 'purposely': 0.004708331036545835, 'grasping': 0.004708331036545835, 'fourth': 0.0030052667108457242, 'meant': 0.004708331036545835, 'follow': 0.0037121022696953087, 'crossing': 0.004708331036545835, 'placekicker': 0.004708331036545835, 'ground': 0.0030052667108457242, 'difficult': 0.0037121022696953087, 'look': 0.0037121022696953087, 'begin': 0.0030052667108457242, 'moves': 0.004708331036545835, 'quarterback': 0.004708331036545835, 'held': 0.004708331036545835, 'stops': 0.004708331036545835, 'zone': 0.004708331036545835, 'work': 0.0030052667108457242, 'anyone': 0.004708331036545835, 'begins': 0.0037121022696953087, 'enter': 0.004708331036545835, 'touchdowns': 0.004708331036545835, 'ball': 0.0037121022696953087, 'uniform': 0.004708331036545835, 'scrimmage': 0.004708331036545835, 'pass': 0.0037121022696953087, 'backs': 0.004708331036545835, 'also': 0.0030052667108457242, 'leader': 0.004708331036545835, 'avoid': 0.003712102269695308 ...

# %%
encoded_docs = encode_documents(tfidf_list)

# Display Words with Highest TF-IDF Value in Each Document
for idx, tfidf in enumerate(tfidf_list):
    sorted_terms = sorted(tfidf.items(), key=lambda x: x[1], reverse=True)[:3]
    print(f"Top words in Document {idx + 1}: {sorted_terms}")

# Display Encoded Document Vectors
print("\nEncoded Document Vectors:")
for idx, vec in enumerate(encoded_docs):
    print(f"Document {idx + 1}: {vec}")
# Out:
# Top words in Document 1: [('prevents', 0.004708331036545835), ('closer', 0.004708331036545835), ('advancing', 0.004708331036545835)]
# Top words in Document 2: [('leather', 0.007758262072365), ('choose', 0.007758262072365), ('always', 0.007758262072365)]
# Top words in Document 3: [('works', 0.0008259873844285151), ('european', 0.0008259873844285151), ('intentionality', 0.0008259873844285151)]
# Top words in Document 4: [('sexual', 0.004085907743868134), ('asking', 0.004085907743868134), ('whole', 0.004085907743868134)]
#
# Encoded Document Vectors:
# Document 1: [0.        0.        0.        ... 0.        0.        0.0543671]
# Document 2: [0. 0. 0. ... 0. 0. 0.]
# Document 3: [0.02122141 0.02122141 0.02122141 ... 0.02122141 0.02122141 0.        ]
# Document 4: [0. 0. 0. ... 0. 0. 0.]
